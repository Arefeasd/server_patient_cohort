# %%
import polars as pl
import pandas as pd
import json 
from pycomorb import comorbidity
import icu_flag
import hosps
import cim10_utils
import comorbidity_utils
import drug
import patient_utils

# %%
unit_mapping = pl.read_parquet("unit_mapping.parquet")
stay = pl.read_parquet("stay.parquet")
document_data = pl.read_parquet("document_data.parquet")
treatments = pl.read_parquet("traitement.parquet")
patient = pl.read_parquet("patient.parquet")

# %%
unit_mapping_icu = icu_flag.add_icu_unit_flag(unit_mapping)

# %%
stay_with_icu = icu_flag.add_icu_flag_to_stay(stay, unit_mapping_icu)

# %%
pl.Config.set_tbl_rows(-1)
stay_with_icu
# Out:
# shape: (24, 13)
# ┌────────────┬────────┬─────────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ patient_id ┆ centre ┆ hosp_id ┆ hosp_admis ┆ … ┆ inclusion_ ┆ unit_name  ┆ unit_grou ┆ icu_unit_ │
# │ ---        ┆ ---    ┆ ---     ┆ sion_datet ┆   ┆ flag       ┆ ---        ┆ p         ┆ flag      │
# │ str        ┆ str    ┆ i64     ┆ ime        ┆   ┆ ---        ┆ str        ┆ ---       ┆ ---       │
# │            ┆        ┆         ┆ ---        ┆   ┆ i64        ┆            ┆ str       ┆ i8        │
# │            ┆        ┆         ┆ datetime[μ ┆   ┆            ┆            ┆           ┆           │
# │            ┆        ┆         ┆ s]         ┆   ┆            ┆            ┆           ┆           │
# ╞════════════╪════════╪═════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ P001       ┆ angers ┆ 1001    ┆ 2015-03-10 ┆ … ┆ 0          ┆ Cardiologi ┆ Cardiolog ┆ 0         │
# │            ┆        ┆         ┆ 09:30:00   ┆   ┆            ┆ e Angers   ┆ ie        ┆           │
# │ P001       ┆ angers ┆ 1002    ┆ 2018-07-04 ┆ … ┆ 1          ┆ Urgences   ┆ Urgences  ┆ 0         │
# │            ┆        ┆         ┆ 11:15:00   ┆   ┆            ┆ Angers     ┆           ┆           │
# │ P001       ┆ angers ┆ 1002    ┆ 2018-07-04 ┆ … ┆ 1          ┆ Pneumologi ┆ Pneumolog ┆ 0         │
# │            ┆        ┆         ┆ 11:15:00   ┆   ┆            ┆ e Angers   ┆ ie        ┆           │
# │ P002       ┆ brest  ┆ 2001    ┆ 2014-06-22 ┆ … ┆ 0          ┆ Médecine   ┆ Médecine  ┆ 0         │
# │            ┆        ┆         ┆ 08:40:00   ┆   ┆            ┆ interne    ┆ interne   ┆           │
# │            ┆        ┆         ┆            ┆   ┆            ┆ Brest      ┆           ┆           │
# │ P002       ┆ brest  ┆ 2002    ┆ 2019-01-18 ┆ … ┆ 1          ┆ Pneumologi ┆ Pneumolog ┆ 0         │
# │            ┆        ┆         ┆ 13:20:00   ┆   ┆            ┆ e Brest    ┆ ie        ┆           │
# │ P003       ┆ nantes ┆ 3001    ┆ 2016-02-05 ┆ … ┆ 0          ┆ Cardiologi ┆ Cardiolog ┆ 0         │
# │            ┆        ┆         ┆ 10:00:00   ┆   ┆            ┆ e Nantes   ┆ ie        ┆           │
# │ P003       ┆ nantes ┆ 3002    ┆ 2019-04-09 ┆ … ┆ 1          ┆ Pneumologi ┆ Pneumolog ┆ 0         │
# │            ┆        ┆         ┆ 09:15:00   ┆   ┆            ┆ e Nantes   ┆ ie        ┆           │
# │ P003       ┆ nantes ┆ 3003    ┆ 2020-10-02 ┆ … ┆ 1          ┆ Urgences   ┆ Urgences  ┆ 0         │
# │            ┆        ┆         ┆ 12:00:00   ┆   ┆            ┆ Nantes     ┆           ┆           │
# │ P003       ┆ nantes ┆ 3003    ┆ 2020-10-02 ┆ … ┆ 1          ┆ Médecine   ┆ Médecine  ┆ 0         │
# │            ┆        ┆         ┆ 12:00:00   ┆   ┆            ┆ interne    ┆ interne   ┆           │
# │            ┆        ┆         ┆            ┆   ┆            ┆ Nantes     ┆           ┆           │
# │ P004       ┆ tours  ┆ 4001    ┆ 2015-11-14 ┆ … ┆ 0          ┆ Cardiologi ┆ Cardiolog ┆ 0         │
# │            ┆        ┆         ┆ 15:00:00   ┆   ┆            ┆ e Tours    ┆ ie        ┆           │
# │ P004       ┆ tours  ┆ 4002    ┆ 2018-03-03 ┆ … ┆ 1          ┆ Urgences   ┆ Urgences  ┆ 0         │
# │            ┆        ┆         ┆ 07:50:00   ┆   ┆            ┆ Tours      ┆           ┆           │
# │ P004       ┆ tours  ┆ 4002    ┆ 2018-03-03 ┆ … ┆ 1          ┆ Réanimatio ┆ Réanimati ┆ 1         │
# │            ┆        ┆         ┆ 07:50:00   ┆   ┆            ┆ n médicale ┆ on        ┆           │
# │            ┆        ┆         ┆            ┆   ┆            ┆ Tours      ┆           ┆           │
# │ P005       ┆ angers ┆ 5001    ┆ 2016-08-19 ┆ … ┆ 0          ┆ Médecine   ┆ Médecine  ┆ 0         │
# │            ┆        ┆         ┆ 11:00:00   ┆   ┆            ┆ interne    ┆ interne   ┆           │
# │            ┆        ┆         ┆            ┆   ┆            ┆ Angers     ┆           ┆           │
# │ P005       ┆ angers ┆ 5002    ┆ 2019-02-01 ┆ … ┆ 1          ┆ Pneumologi ┆ Pneumolog ┆ 0         │
# │            ┆        ┆         ┆ 14:10:00   ┆   ┆            ┆ e Angers   ┆ ie        ┆           │
# │ P006       ┆ brest  ┆ 6001    ┆ 2017-05-06 ┆ … ┆ 0          ┆ Cardiologi ┆ Cardiolog ┆ 0         │
# │            ┆        ┆         ┆ 09:20:00   ┆   ┆            ┆ e Brest    ┆ ie        ┆           │
# │ P006       ┆ brest  ┆ 6002    ┆ 2020-06-17 ┆ … ┆ 1          ┆ Pneumologi ┆ Pneumolog ┆ 0         │
# │            ┆        ┆         ┆ 10:45:00   ┆   ┆            ┆ e Brest    ┆ ie        ┆           │
# │ P007       ┆ nantes ┆ 7001    ┆ 2020-07-22 ┆ … ┆ 1          ┆ Pneumologi ┆ Pneumolog ┆ 0         │
# │            ┆        ┆         ┆ 08:30:00   ┆   ┆            ┆ e Nantes   ┆ ie        ┆           │
# │ P008       ┆ tours  ┆ 8001    ┆ 2017-09-10 ┆ … ┆ 0          ┆ Médecine   ┆ Médecine  ┆ 0         │
# │            ┆        ┆         ┆ 13:00:00   ┆   ┆            ┆ interne    ┆ interne   ┆           │
# │            ┆        ┆         ┆            ┆   ┆            ┆ Tours      ┆           ┆           │
# │ P008       ┆ tours  ┆ 8002    ┆ 2020-12-05 ┆ … ┆ 1          ┆ Urgences   ┆ Urgences  ┆ 0         │
# │            ┆        ┆         ┆ 06:45:00   ┆   ┆            ┆ Tours      ┆           ┆           │
# │ P008       ┆ tours  ┆ 8002    ┆ 2020-12-05 ┆ … ┆ 1          ┆ Réanimatio ┆ Réanimati ┆ 1         │
# │            ┆        ┆         ┆ 06:45:00   ┆   ┆            ┆ n médicale ┆ on        ┆           │
# │            ┆        ┆         ┆            ┆   ┆            ┆ Tours      ┆           ┆           │
# │ P009       ┆ angers ┆ 9001    ┆ 2014-12-03 ┆ … ┆ 0          ┆ Cardiologi ┆ Cardiolog ┆ 0         │
# │            ┆        ┆         ┆ 10:15:00   ┆   ┆            ┆ e Angers   ┆ ie        ┆           │
# │ P009       ┆ angers ┆ 9002    ┆ 2017-01-26 ┆ … ┆ 1          ┆ Pneumologi ┆ Pneumolog ┆ 0         │
# │            ┆        ┆         ┆ 09:00:00   ┆   ┆            ┆ e Angers   ┆ ie        ┆           │
# │ P010       ┆ brest  ┆ 10001   ┆ 2015-04-18 ┆ … ┆ 0          ┆ Cardiologi ┆ Cardiolog ┆ 0         │
# │            ┆        ┆         ┆ 12:20:00   ┆   ┆            ┆ e Brest    ┆ ie        ┆           │
# │ P010       ┆ brest  ┆ 10002   ┆ 2020-03-21 ┆ … ┆ 1          ┆ Pneumologi ┆ Pneumolog ┆ 0         │
# │            ┆        ┆         ┆ 16:30:00   ┆   ┆            ┆ e Brest    ┆ ie        ┆           │
# └────────────┴────────┴─────────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
hosp = hosps.get_hosp(stay_with_icu)

# %%
stay_with_icu.shape
# Out:
# (24, 13)

# %%
hosp.shape
# Out:
# (20, 7)

# %%
hosp.head()
# Out:
# shape: (5, 7)
# ┌────────────┬─────────┬────────┬────────────────┬────────────────┬────────────────┬───────────────┐
# │ patient_id ┆ hosp_id ┆ centre ┆ hosp_admission ┆ hosp_discharge ┆ inclusion_flag ┆ icu_stay_flag │
# │ ---        ┆ ---     ┆ ---    ┆ _datetime      ┆ _datetime      ┆ ---            ┆ ---           │
# │ str        ┆ i64     ┆ str    ┆ ---            ┆ ---            ┆ i64            ┆ i8            │
# │            ┆         ┆        ┆ datetime[μs]   ┆ datetime[μs]   ┆                ┆               │
# ╞════════════╪═════════╪════════╪════════════════╪════════════════╪════════════════╪═══════════════╡
# │ P001       ┆ 1001    ┆ angers ┆ 2015-03-10     ┆ 2015-03-16     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 09:30:00       ┆ 14:00:00       ┆                ┆               │
# │ P001       ┆ 1002    ┆ angers ┆ 2018-07-04     ┆ 2018-07-12     ┆ 1              ┆ 0             │
# │            ┆         ┆        ┆ 11:15:00       ┆ 10:00:00       ┆                ┆               │
# │ P002       ┆ 2001    ┆ brest  ┆ 2014-06-22     ┆ 2014-06-28     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 08:40:00       ┆ 15:30:00       ┆                ┆               │
# │ P002       ┆ 2002    ┆ brest  ┆ 2019-01-18     ┆ 2019-01-25     ┆ 1              ┆ 0             │
# │            ┆         ┆        ┆ 13:20:00       ┆ 11:00:00       ┆                ┆               │
# │ P003       ┆ 3001    ┆ nantes ┆ 2016-02-05     ┆ 2016-02-11     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 10:00:00       ┆ 16:00:00       ┆                ┆               │
# └────────────┴─────────┴────────┴────────────────┴────────────────┴────────────────┴───────────────┘

# %%
pl.Config.set_tbl_rows(-1)
hosp
# Out:
# shape: (20, 7)
# ┌────────────┬─────────┬────────┬────────────────┬────────────────┬────────────────┬───────────────┐
# │ patient_id ┆ hosp_id ┆ centre ┆ hosp_admission ┆ hosp_discharge ┆ inclusion_flag ┆ icu_stay_flag │
# │ ---        ┆ ---     ┆ ---    ┆ _datetime      ┆ _datetime      ┆ ---            ┆ ---           │
# │ str        ┆ i64     ┆ str    ┆ ---            ┆ ---            ┆ i64            ┆ i8            │
# │            ┆         ┆        ┆ datetime[μs]   ┆ datetime[μs]   ┆                ┆               │
# ╞════════════╪═════════╪════════╪════════════════╪════════════════╪════════════════╪═══════════════╡
# │ P001       ┆ 1001    ┆ angers ┆ 2015-03-10     ┆ 2015-03-16     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 09:30:00       ┆ 14:00:00       ┆                ┆               │
# │ P001       ┆ 1002    ┆ angers ┆ 2018-07-04     ┆ 2018-07-12     ┆ 1              ┆ 0             │
# │            ┆         ┆        ┆ 11:15:00       ┆ 10:00:00       ┆                ┆               │
# │ P002       ┆ 2001    ┆ brest  ┆ 2014-06-22     ┆ 2014-06-28     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 08:40:00       ┆ 15:30:00       ┆                ┆               │
# │ P002       ┆ 2002    ┆ brest  ┆ 2019-01-18     ┆ 2019-01-25     ┆ 1              ┆ 0             │
# │            ┆         ┆        ┆ 13:20:00       ┆ 11:00:00       ┆                ┆               │
# │ P003       ┆ 3001    ┆ nantes ┆ 2016-02-05     ┆ 2016-02-11     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 10:00:00       ┆ 16:00:00       ┆                ┆               │
# │ P003       ┆ 3002    ┆ nantes ┆ 2019-04-09     ┆ 2019-04-18     ┆ 1              ┆ 0             │
# │            ┆         ┆        ┆ 09:15:00       ┆ 10:30:00       ┆                ┆               │
# │ P003       ┆ 3003    ┆ nantes ┆ 2020-10-02     ┆ 2020-10-09     ┆ 1              ┆ 0             │
# │            ┆         ┆        ┆ 12:00:00       ┆ 09:45:00       ┆                ┆               │
# │ P004       ┆ 4001    ┆ tours  ┆ 2015-11-14     ┆ 2015-11-20     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 15:00:00       ┆ 13:00:00       ┆                ┆               │
# │ P004       ┆ 4002    ┆ tours  ┆ 2018-03-03     ┆ 2018-03-18     ┆ 1              ┆ 1             │
# │            ┆         ┆        ┆ 07:50:00       ┆ 12:20:00       ┆                ┆               │
# │ P005       ┆ 5001    ┆ angers ┆ 2016-08-19     ┆ 2016-08-24     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 11:00:00       ┆ 10:00:00       ┆                ┆               │
# │ P005       ┆ 5002    ┆ angers ┆ 2019-02-01     ┆ 2019-02-08     ┆ 1              ┆ 0             │
# │            ┆         ┆        ┆ 14:10:00       ┆ 15:00:00       ┆                ┆               │
# │ P006       ┆ 6001    ┆ brest  ┆ 2017-05-06     ┆ 2017-05-12     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 09:20:00       ┆ 11:30:00       ┆                ┆               │
# │ P006       ┆ 6002    ┆ brest  ┆ 2020-06-17     ┆ 2020-06-24     ┆ 1              ┆ 0             │
# │            ┆         ┆        ┆ 10:45:00       ┆ 12:00:00       ┆                ┆               │
# │ P007       ┆ 7001    ┆ nantes ┆ 2020-07-22     ┆ 2020-07-29     ┆ 1              ┆ 0             │
# │            ┆         ┆        ┆ 08:30:00       ┆ 10:15:00       ┆                ┆               │
# │ P008       ┆ 8001    ┆ tours  ┆ 2017-09-10     ┆ 2017-09-16     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 13:00:00       ┆ 09:30:00       ┆                ┆               │
# │ P008       ┆ 8002    ┆ tours  ┆ 2020-12-05     ┆ 2020-12-20     ┆ 1              ┆ 1             │
# │            ┆         ┆        ┆ 06:45:00       ┆ 16:00:00       ┆                ┆               │
# │ P009       ┆ 9001    ┆ angers ┆ 2014-12-03     ┆ 2014-12-09     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 10:15:00       ┆ 14:20:00       ┆                ┆               │
# │ P009       ┆ 9002    ┆ angers ┆ 2017-01-26     ┆ 2017-02-03     ┆ 1              ┆ 0             │
# │            ┆         ┆        ┆ 09:00:00       ┆ 11:45:00       ┆                ┆               │
# │ P010       ┆ 10001   ┆ brest  ┆ 2015-04-18     ┆ 2015-04-23     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 12:20:00       ┆ 10:00:00       ┆                ┆               │
# │ P010       ┆ 10002   ┆ brest  ┆ 2020-03-21     ┆ 2020-04-02     ┆ 1              ┆ 0             │
# │            ┆         ┆        ┆ 16:30:00       ┆ 09:00:00       ┆                ┆               │
# └────────────┴─────────┴────────┴────────────────┴────────────────┴────────────────┴───────────────┘

# %%
inclusion_hosps = hosps.get_inclusion_hosps(hosp)

# %%
pl.Config.set_tbl_rows(-1)
inclusion_hosps
# Out:
# shape: (11, 7)
# ┌────────────┬─────────┬────────┬────────────────┬────────────────┬────────────────┬───────────────┐
# │ patient_id ┆ hosp_id ┆ centre ┆ hosp_admission ┆ hosp_discharge ┆ inclusion_flag ┆ icu_stay_flag │
# │ ---        ┆ ---     ┆ ---    ┆ _datetime      ┆ _datetime      ┆ ---            ┆ ---           │
# │ str        ┆ i64     ┆ str    ┆ ---            ┆ ---            ┆ i64            ┆ i8            │
# │            ┆         ┆        ┆ datetime[μs]   ┆ datetime[μs]   ┆                ┆               │
# ╞════════════╪═════════╪════════╪════════════════╪════════════════╪════════════════╪═══════════════╡
# │ P001       ┆ 1002    ┆ angers ┆ 2018-07-04     ┆ 2018-07-12     ┆ 1              ┆ 0             │
# │            ┆         ┆        ┆ 11:15:00       ┆ 10:00:00       ┆                ┆               │
# │ P002       ┆ 2002    ┆ brest  ┆ 2019-01-18     ┆ 2019-01-25     ┆ 1              ┆ 0             │
# │            ┆         ┆        ┆ 13:20:00       ┆ 11:00:00       ┆                ┆               │
# │ P003       ┆ 3002    ┆ nantes ┆ 2019-04-09     ┆ 2019-04-18     ┆ 1              ┆ 0             │
# │            ┆         ┆        ┆ 09:15:00       ┆ 10:30:00       ┆                ┆               │
# │ P003       ┆ 3003    ┆ nantes ┆ 2020-10-02     ┆ 2020-10-09     ┆ 1              ┆ 0             │
# │            ┆         ┆        ┆ 12:00:00       ┆ 09:45:00       ┆                ┆               │
# │ P004       ┆ 4002    ┆ tours  ┆ 2018-03-03     ┆ 2018-03-18     ┆ 1              ┆ 1             │
# │            ┆         ┆        ┆ 07:50:00       ┆ 12:20:00       ┆                ┆               │
# │ P005       ┆ 5002    ┆ angers ┆ 2019-02-01     ┆ 2019-02-08     ┆ 1              ┆ 0             │
# │            ┆         ┆        ┆ 14:10:00       ┆ 15:00:00       ┆                ┆               │
# │ P006       ┆ 6002    ┆ brest  ┆ 2020-06-17     ┆ 2020-06-24     ┆ 1              ┆ 0             │
# │            ┆         ┆        ┆ 10:45:00       ┆ 12:00:00       ┆                ┆               │
# │ P007       ┆ 7001    ┆ nantes ┆ 2020-07-22     ┆ 2020-07-29     ┆ 1              ┆ 0             │
# │            ┆         ┆        ┆ 08:30:00       ┆ 10:15:00       ┆                ┆               │
# │ P008       ┆ 8002    ┆ tours  ┆ 2020-12-05     ┆ 2020-12-20     ┆ 1              ┆ 1             │
# │            ┆         ┆        ┆ 06:45:00       ┆ 16:00:00       ┆                ┆               │
# │ P009       ┆ 9002    ┆ angers ┆ 2017-01-26     ┆ 2017-02-03     ┆ 1              ┆ 0             │
# │            ┆         ┆        ┆ 09:00:00       ┆ 11:45:00       ┆                ┆               │
# │ P010       ┆ 10002   ┆ brest  ┆ 2020-03-21     ┆ 2020-04-02     ┆ 1              ┆ 0             │
# │            ┆         ┆        ┆ 16:30:00       ┆ 09:00:00       ┆                ┆               │
# └────────────┴─────────┴────────┴────────────────┴────────────────┴────────────────┴───────────────┘

# %%
first_inclusion_hosps = hosps.get_first_inclusion_hosps(inclusion_hosps)

# %%
pl.Config.set_tbl_rows(-1)
first_inclusion_hosps
# Out:
# shape: (10, 7)
# ┌────────────┬─────────┬────────┬────────────────┬────────────────┬────────────────┬───────────────┐
# │ patient_id ┆ hosp_id ┆ centre ┆ hosp_admission ┆ hosp_discharge ┆ inclusion_flag ┆ icu_stay_flag │
# │ ---        ┆ ---     ┆ ---    ┆ _datetime      ┆ _datetime      ┆ ---            ┆ ---           │
# │ str        ┆ i64     ┆ str    ┆ ---            ┆ ---            ┆ i64            ┆ i8            │
# │            ┆         ┆        ┆ datetime[μs]   ┆ datetime[μs]   ┆                ┆               │
# ╞════════════╪═════════╪════════╪════════════════╪════════════════╪════════════════╪═══════════════╡
# │ P001       ┆ 1002    ┆ angers ┆ 2018-07-04     ┆ 2018-07-12     ┆ 1              ┆ 0             │
# │            ┆         ┆        ┆ 11:15:00       ┆ 10:00:00       ┆                ┆               │
# │ P002       ┆ 2002    ┆ brest  ┆ 2019-01-18     ┆ 2019-01-25     ┆ 1              ┆ 0             │
# │            ┆         ┆        ┆ 13:20:00       ┆ 11:00:00       ┆                ┆               │
# │ P003       ┆ 3002    ┆ nantes ┆ 2019-04-09     ┆ 2019-04-18     ┆ 1              ┆ 0             │
# │            ┆         ┆        ┆ 09:15:00       ┆ 10:30:00       ┆                ┆               │
# │ P004       ┆ 4002    ┆ tours  ┆ 2018-03-03     ┆ 2018-03-18     ┆ 1              ┆ 1             │
# │            ┆         ┆        ┆ 07:50:00       ┆ 12:20:00       ┆                ┆               │
# │ P005       ┆ 5002    ┆ angers ┆ 2019-02-01     ┆ 2019-02-08     ┆ 1              ┆ 0             │
# │            ┆         ┆        ┆ 14:10:00       ┆ 15:00:00       ┆                ┆               │
# │ P006       ┆ 6002    ┆ brest  ┆ 2020-06-17     ┆ 2020-06-24     ┆ 1              ┆ 0             │
# │            ┆         ┆        ┆ 10:45:00       ┆ 12:00:00       ┆                ┆               │
# │ P007       ┆ 7001    ┆ nantes ┆ 2020-07-22     ┆ 2020-07-29     ┆ 1              ┆ 0             │
# │            ┆         ┆        ┆ 08:30:00       ┆ 10:15:00       ┆                ┆               │
# │ P008       ┆ 8002    ┆ tours  ┆ 2020-12-05     ┆ 2020-12-20     ┆ 1              ┆ 1             │
# │            ┆         ┆        ┆ 06:45:00       ┆ 16:00:00       ┆                ┆               │
# │ P009       ┆ 9002    ┆ angers ┆ 2017-01-26     ┆ 2017-02-03     ┆ 1              ┆ 0             │
# │            ┆         ┆        ┆ 09:00:00       ┆ 11:45:00       ┆                ┆               │
# │ P010       ┆ 10002   ┆ brest  ┆ 2020-03-21     ┆ 2020-04-02     ┆ 1              ┆ 0             │
# │            ┆         ┆        ┆ 16:30:00       ┆ 09:00:00       ┆                ┆               │
# └────────────┴─────────┴────────┴────────────────┴────────────────┴────────────────┴───────────────┘

# %%
preceding_hosps = hosps.get_preceding_hosps(hosp)

# %%
pl.Config.set_tbl_rows(-1)
preceding_hosps
# Out:
# shape: (9, 7)
# ┌────────────┬─────────┬────────┬────────────────┬────────────────┬────────────────┬───────────────┐
# │ patient_id ┆ hosp_id ┆ centre ┆ hosp_admission ┆ hosp_discharge ┆ inclusion_flag ┆ icu_stay_flag │
# │ ---        ┆ ---     ┆ ---    ┆ _datetime      ┆ _datetime      ┆ ---            ┆ ---           │
# │ str        ┆ i64     ┆ str    ┆ ---            ┆ ---            ┆ i64            ┆ i8            │
# │            ┆         ┆        ┆ datetime[μs]   ┆ datetime[μs]   ┆                ┆               │
# ╞════════════╪═════════╪════════╪════════════════╪════════════════╪════════════════╪═══════════════╡
# │ P001       ┆ 1001    ┆ angers ┆ 2015-03-10     ┆ 2015-03-16     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 09:30:00       ┆ 14:00:00       ┆                ┆               │
# │ P002       ┆ 2001    ┆ brest  ┆ 2014-06-22     ┆ 2014-06-28     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 08:40:00       ┆ 15:30:00       ┆                ┆               │
# │ P003       ┆ 3001    ┆ nantes ┆ 2016-02-05     ┆ 2016-02-11     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 10:00:00       ┆ 16:00:00       ┆                ┆               │
# │ P004       ┆ 4001    ┆ tours  ┆ 2015-11-14     ┆ 2015-11-20     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 15:00:00       ┆ 13:00:00       ┆                ┆               │
# │ P005       ┆ 5001    ┆ angers ┆ 2016-08-19     ┆ 2016-08-24     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 11:00:00       ┆ 10:00:00       ┆                ┆               │
# │ P006       ┆ 6001    ┆ brest  ┆ 2017-05-06     ┆ 2017-05-12     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 09:20:00       ┆ 11:30:00       ┆                ┆               │
# │ P008       ┆ 8001    ┆ tours  ┆ 2017-09-10     ┆ 2017-09-16     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 13:00:00       ┆ 09:30:00       ┆                ┆               │
# │ P009       ┆ 9001    ┆ angers ┆ 2014-12-03     ┆ 2014-12-09     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 10:15:00       ┆ 14:20:00       ┆                ┆               │
# │ P010       ┆ 10001   ┆ brest  ┆ 2015-04-18     ┆ 2015-04-23     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 12:20:00       ┆ 10:00:00       ┆                ┆               │
# └────────────┴─────────┴────────┴────────────────┴────────────────┴────────────────┴───────────────┘

# %%
included_patients = hosps.get_included_patients(first_inclusion_hosps)

# %%
included_patients
# Out:
# shape: (10, 1)
# ┌────────────┐
# │ patient_id │
# │ ---        │
# │ str        │
# ╞════════════╡
# │ P001       │
# │ P002       │
# │ P003       │
# │ P004       │
# │ P005       │
# │ P006       │
# │ P007       │
# │ P008       │
# │ P009       │
# │ P010       │
# └────────────┘

# %%
preceding_hosps_of_included_patients = hosps.get_preceding_hosps_of_included_patients(preceding_hosps, included_patients)

# %%
pl.Config.set_tbl_rows(-1)
preceding_hosps_of_included_patients
# Out:
# shape: (9, 7)
# ┌────────────┬─────────┬────────┬────────────────┬────────────────┬────────────────┬───────────────┐
# │ patient_id ┆ hosp_id ┆ centre ┆ hosp_admission ┆ hosp_discharge ┆ inclusion_flag ┆ icu_stay_flag │
# │ ---        ┆ ---     ┆ ---    ┆ _datetime      ┆ _datetime      ┆ ---            ┆ ---           │
# │ str        ┆ i64     ┆ str    ┆ ---            ┆ ---            ┆ i64            ┆ i8            │
# │            ┆         ┆        ┆ datetime[μs]   ┆ datetime[μs]   ┆                ┆               │
# ╞════════════╪═════════╪════════╪════════════════╪════════════════╪════════════════╪═══════════════╡
# │ P001       ┆ 1001    ┆ angers ┆ 2015-03-10     ┆ 2015-03-16     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 09:30:00       ┆ 14:00:00       ┆                ┆               │
# │ P002       ┆ 2001    ┆ brest  ┆ 2014-06-22     ┆ 2014-06-28     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 08:40:00       ┆ 15:30:00       ┆                ┆               │
# │ P003       ┆ 3001    ┆ nantes ┆ 2016-02-05     ┆ 2016-02-11     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 10:00:00       ┆ 16:00:00       ┆                ┆               │
# │ P004       ┆ 4001    ┆ tours  ┆ 2015-11-14     ┆ 2015-11-20     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 15:00:00       ┆ 13:00:00       ┆                ┆               │
# │ P005       ┆ 5001    ┆ angers ┆ 2016-08-19     ┆ 2016-08-24     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 11:00:00       ┆ 10:00:00       ┆                ┆               │
# │ P006       ┆ 6001    ┆ brest  ┆ 2017-05-06     ┆ 2017-05-12     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 09:20:00       ┆ 11:30:00       ┆                ┆               │
# │ P008       ┆ 8001    ┆ tours  ┆ 2017-09-10     ┆ 2017-09-16     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 13:00:00       ┆ 09:30:00       ┆                ┆               │
# │ P009       ┆ 9001    ┆ angers ┆ 2014-12-03     ┆ 2014-12-09     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 10:15:00       ┆ 14:20:00       ┆                ┆               │
# │ P010       ┆ 10001   ┆ brest  ┆ 2015-04-18     ┆ 2015-04-23     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 12:20:00       ┆ 10:00:00       ┆                ┆               │
# └────────────┴─────────┴────────┴────────────────┴────────────────┴────────────────┴───────────────┘

# %%
pl.Config.set_tbl_rows(-1)
document_data
# Out:
# shape: (20, 12)
# ┌────────────┬────────┬─────────┬─────────┬───┬──────────────┬──────────────┬─────────────┬────────┐
# │ patient_id ┆ centre ┆ hosp_id ┆ stay_id ┆ … ┆ datetime     ┆ numeric_valu ┆ text_value  ┆ unit   │
# │ ---        ┆ ---    ┆ ---     ┆ ---     ┆   ┆ ---          ┆ e            ┆ ---         ┆ ---    │
# │ str        ┆ str    ┆ i64     ┆ i64     ┆   ┆ datetime[μs] ┆ ---          ┆ str         ┆ str    │
# │            ┆        ┆         ┆         ┆   ┆              ┆ f64          ┆             ┆        │
# ╞════════════╪════════╪═════════╪═════════╪═══╪══════════════╪══════════════╪═════════════╪════════╡
# │ P001       ┆ angers ┆ 1001    ┆ 1       ┆ … ┆ 2015-03-12   ┆ null         ┆ DA          ┆ null   │
# │            ┆        ┆         ┆         ┆   ┆ 10:20:00     ┆              ┆             ┆        │
# │ P001       ┆ angers ┆ 1001    ┆ 1       ┆ … ┆ 2015-03-12   ┆ null         ┆ DA          ┆ null   │
# │            ┆        ┆         ┆         ┆   ┆ 10:25:00     ┆              ┆             ┆        │
# │ P001       ┆ angers ┆ 1002    ┆ 3       ┆ … ┆ 2018-07-05   ┆ null         ┆ DP          ┆ null   │
# │            ┆        ┆         ┆         ┆   ┆ 11:10:00     ┆              ┆             ┆        │
# │ P002       ┆ brest  ┆ 2001    ┆ 4       ┆ … ┆ 2014-06-23   ┆ null         ┆ DA          ┆ null   │
# │            ┆        ┆         ┆         ┆   ┆ 09:30:00     ┆              ┆             ┆        │
# │ P002       ┆ brest  ┆ 2002    ┆ 5       ┆ … ┆ 2019-01-19   ┆ null         ┆ DP          ┆ null   │
# │            ┆        ┆         ┆         ┆   ┆ 10:15:00     ┆              ┆             ┆        │
# │ P003       ┆ nantes ┆ 3001    ┆ 6       ┆ … ┆ 2016-02-06   ┆ null         ┆ DA          ┆ null   │
# │            ┆        ┆         ┆         ┆   ┆ 14:00:00     ┆              ┆             ┆        │
# │ P003       ┆ nantes ┆ 3001    ┆ 6       ┆ … ┆ 2016-02-06   ┆ null         ┆ DA          ┆ null   │
# │            ┆        ┆         ┆         ┆   ┆ 14:10:00     ┆              ┆             ┆        │
# │ P003       ┆ nantes ┆ 3002    ┆ 7       ┆ … ┆ 2019-04-10   ┆ null         ┆ DP          ┆ null   │
# │            ┆        ┆         ┆         ┆   ┆ 08:45:00     ┆              ┆             ┆        │
# │ P004       ┆ tours  ┆ 4001    ┆ 10      ┆ … ┆ 2015-11-15   ┆ null         ┆ DA          ┆ null   │
# │            ┆        ┆         ┆         ┆   ┆ 16:30:00     ┆              ┆             ┆        │
# │ P004       ┆ tours  ┆ 4002    ┆ 12      ┆ … ┆ 2018-03-05   ┆ null         ┆ DA          ┆ null   │
# │            ┆        ┆         ┆         ┆   ┆ 09:20:00     ┆              ┆             ┆        │
# │ P004       ┆ tours  ┆ 4002    ┆ 12      ┆ … ┆ 2018-03-05   ┆ null         ┆ DA          ┆ null   │
# │            ┆        ┆         ┆         ┆   ┆ 09:25:00     ┆              ┆             ┆        │
# │ P004       ┆ tours  ┆ 4002    ┆ 12      ┆ … ┆ 2018-03-06   ┆ null         ┆ Acte        ┆ null   │
# │            ┆        ┆         ┆         ┆   ┆ 11:00:00     ┆              ┆ réalisé     ┆        │
# │ P005       ┆ angers ┆ 5001    ┆ 13      ┆ … ┆ 2016-08-20   ┆ null         ┆ DA          ┆ null   │
# │            ┆        ┆         ┆         ┆   ┆ 10:15:00     ┆              ┆             ┆        │
# │ P005       ┆ angers ┆ 5001    ┆ 13      ┆ … ┆ 2016-08-20   ┆ null         ┆ DA          ┆ null   │
# │            ┆        ┆         ┆         ┆   ┆ 10:20:00     ┆              ┆             ┆        │
# │ P006       ┆ brest  ┆ 6002    ┆ 16      ┆ … ┆ 2020-06-18   ┆ 142.0        ┆ null        ┆ µmol/L │
# │            ┆        ┆         ┆         ┆   ┆ 07:30:00     ┆              ┆             ┆        │
# │ P008       ┆ tours  ┆ 8001    ┆ 18      ┆ … ┆ 2017-09-11   ┆ null         ┆ DA          ┆ null   │
# │            ┆        ┆         ┆         ┆   ┆ 13:40:00     ┆              ┆             ┆        │
# │ P008       ┆ tours  ┆ 8002    ┆ 20      ┆ … ┆ 2020-12-06   ┆ null         ┆ DP          ┆ null   │
# │            ┆        ┆         ┆         ┆   ┆ 09:10:00     ┆              ┆             ┆        │
# │ P008       ┆ tours  ┆ 8002    ┆ 20      ┆ … ┆ 2020-12-06   ┆ 72.5         ┆ null        ┆ mmHg   │
# │            ┆        ┆         ┆         ┆   ┆ 09:30:00     ┆              ┆             ┆        │
# │ P010       ┆ brest  ┆ 10001   ┆ 23      ┆ … ┆ 2015-04-19   ┆ null         ┆ DA          ┆ null   │
# │            ┆        ┆         ┆         ┆   ┆ 09:50:00     ┆              ┆             ┆        │
# │ P010       ┆ brest  ┆ 10002   ┆ 24      ┆ … ┆ 2020-03-22   ┆ null         ┆ DP          ┆ null   │
# │            ┆        ┆         ┆         ┆   ┆ 10:10:00     ┆              ┆             ┆        │
# └────────────┴────────┴─────────┴─────────┴───┴──────────────┴──────────────┴─────────────┴────────┘

# %%
document_data = document_data.with_columns(
    pl.when(pl.col("terminology_code") == "CIM-10")
    .then(pl.lit("cim10"))
    .otherwise(pl.col("terminology_code"))
    .alias("terminology_code")
)

# %%
cim10 = cim10_utils.load_cim10(document_data)

# %%
pl.Config.set_tbl_rows(-1)
cim10.sort(pl.col("patient_id"))
# Out:
# shape: (17, 4)
# ┌────────────┬─────────┬──────────────┬────────┐
# │ patient_id ┆ hosp_id ┆ concept_code ┆ centre │
# │ ---        ┆ ---     ┆ ---          ┆ ---    │
# │ str        ┆ i64     ┆ str          ┆ str    │
# ╞════════════╪═════════╪══════════════╪════════╡
# │ P001       ┆ 1002    ┆ J960         ┆ angers │
# │ P001       ┆ 1001    ┆ I48          ┆ angers │
# │ P001       ┆ 1001    ┆ I25          ┆ angers │
# │ P002       ┆ 2001    ┆ E119         ┆ brest  │
# │ P002       ┆ 2002    ┆ J960         ┆ brest  │
# │ P003       ┆ 3001    ┆ N18          ┆ nantes │
# │ P003       ┆ 3001    ┆ I50          ┆ nantes │
# │ P003       ┆ 3002    ┆ J960         ┆ nantes │
# │ P004       ┆ 4002    ┆ Z950         ┆ tours  │
# │ P004       ┆ 4001    ┆ I21          ┆ tours  │
# │ P004       ┆ 4002    ┆ I50          ┆ tours  │
# │ P005       ┆ 5001    ┆ E785         ┆ angers │
# │ P005       ┆ 5001    ┆ C349         ┆ angers │
# │ P008       ┆ 8002    ┆ J960         ┆ tours  │
# │ P008       ┆ 8001    ┆ I693         ┆ tours  │
# │ P010       ┆ 10001   ┆ I48          ┆ brest  │
# │ P010       ┆ 10002   ┆ J960         ┆ brest  │
# └────────────┴─────────┴──────────────┴────────┘

# %%
preceding_hosps_of_included_patients
# Out:
# shape: (9, 7)
# ┌────────────┬─────────┬────────┬────────────────┬────────────────┬────────────────┬───────────────┐
# │ patient_id ┆ hosp_id ┆ centre ┆ hosp_admission ┆ hosp_discharge ┆ inclusion_flag ┆ icu_stay_flag │
# │ ---        ┆ ---     ┆ ---    ┆ _datetime      ┆ _datetime      ┆ ---            ┆ ---           │
# │ str        ┆ i64     ┆ str    ┆ ---            ┆ ---            ┆ i64            ┆ i8            │
# │            ┆         ┆        ┆ datetime[μs]   ┆ datetime[μs]   ┆                ┆               │
# ╞════════════╪═════════╪════════╪════════════════╪════════════════╪════════════════╪═══════════════╡
# │ P001       ┆ 1001    ┆ angers ┆ 2015-03-10     ┆ 2015-03-16     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 09:30:00       ┆ 14:00:00       ┆                ┆               │
# │ P002       ┆ 2001    ┆ brest  ┆ 2014-06-22     ┆ 2014-06-28     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 08:40:00       ┆ 15:30:00       ┆                ┆               │
# │ P003       ┆ 3001    ┆ nantes ┆ 2016-02-05     ┆ 2016-02-11     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 10:00:00       ┆ 16:00:00       ┆                ┆               │
# │ P004       ┆ 4001    ┆ tours  ┆ 2015-11-14     ┆ 2015-11-20     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 15:00:00       ┆ 13:00:00       ┆                ┆               │
# │ P005       ┆ 5001    ┆ angers ┆ 2016-08-19     ┆ 2016-08-24     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 11:00:00       ┆ 10:00:00       ┆                ┆               │
# │ P006       ┆ 6001    ┆ brest  ┆ 2017-05-06     ┆ 2017-05-12     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 09:20:00       ┆ 11:30:00       ┆                ┆               │
# │ P008       ┆ 8001    ┆ tours  ┆ 2017-09-10     ┆ 2017-09-16     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 13:00:00       ┆ 09:30:00       ┆                ┆               │
# │ P009       ┆ 9001    ┆ angers ┆ 2014-12-03     ┆ 2014-12-09     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 10:15:00       ┆ 14:20:00       ┆                ┆               │
# │ P010       ┆ 10001   ┆ brest  ┆ 2015-04-18     ┆ 2015-04-23     ┆ 0              ┆ 0             │
# │            ┆         ┆        ┆ 12:20:00       ┆ 10:00:00       ┆                ┆               │
# └────────────┴─────────┴────────┴────────────────┴────────────────┴────────────────┴───────────────┘

# %%
preceding_hosps_of_included_patients_with_cim10 = cim10_utils.get_preceding_hosps_of_included_patients_with_cim10(preceding_hosps_of_included_patients, cim10)

# %%
pl.Config.set_tbl_rows(-1)
preceding_hosps_of_included_patients_with_cim10
# Out:
# shape: (12, 8)
# ┌────────────┬─────────┬────────┬─────────────┬─────────────┬────────────┬────────────┬────────────┐
# │ patient_id ┆ hosp_id ┆ centre ┆ hosp_admiss ┆ hosp_discha ┆ inclusion_ ┆ icu_stay_f ┆ concept_co │
# │ ---        ┆ ---     ┆ ---    ┆ ion_datetim ┆ rge_datetim ┆ flag       ┆ lag        ┆ de         │
# │ str        ┆ i64     ┆ str    ┆ e           ┆ e           ┆ ---        ┆ ---        ┆ ---        │
# │            ┆         ┆        ┆ ---         ┆ ---         ┆ i64        ┆ i8         ┆ str        │
# │            ┆         ┆        ┆ datetime[μs ┆ datetime[μs ┆            ┆            ┆            │
# │            ┆         ┆        ┆ ]           ┆ ]           ┆            ┆            ┆            │
# ╞════════════╪═════════╪════════╪═════════════╪═════════════╪════════════╪════════════╪════════════╡
# │ P001       ┆ 1001    ┆ angers ┆ 2015-03-10  ┆ 2015-03-16  ┆ 0          ┆ 0          ┆ I48        │
# │            ┆         ┆        ┆ 09:30:00    ┆ 14:00:00    ┆            ┆            ┆            │
# │ P001       ┆ 1001    ┆ angers ┆ 2015-03-10  ┆ 2015-03-16  ┆ 0          ┆ 0          ┆ I25        │
# │            ┆         ┆        ┆ 09:30:00    ┆ 14:00:00    ┆            ┆            ┆            │
# │ P002       ┆ 2001    ┆ brest  ┆ 2014-06-22  ┆ 2014-06-28  ┆ 0          ┆ 0          ┆ E119       │
# │            ┆         ┆        ┆ 08:40:00    ┆ 15:30:00    ┆            ┆            ┆            │
# │ P003       ┆ 3001    ┆ nantes ┆ 2016-02-05  ┆ 2016-02-11  ┆ 0          ┆ 0          ┆ N18        │
# │            ┆         ┆        ┆ 10:00:00    ┆ 16:00:00    ┆            ┆            ┆            │
# │ P003       ┆ 3001    ┆ nantes ┆ 2016-02-05  ┆ 2016-02-11  ┆ 0          ┆ 0          ┆ I50        │
# │            ┆         ┆        ┆ 10:00:00    ┆ 16:00:00    ┆            ┆            ┆            │
# │ P004       ┆ 4001    ┆ tours  ┆ 2015-11-14  ┆ 2015-11-20  ┆ 0          ┆ 0          ┆ I21        │
# │            ┆         ┆        ┆ 15:00:00    ┆ 13:00:00    ┆            ┆            ┆            │
# │ P005       ┆ 5001    ┆ angers ┆ 2016-08-19  ┆ 2016-08-24  ┆ 0          ┆ 0          ┆ E785       │
# │            ┆         ┆        ┆ 11:00:00    ┆ 10:00:00    ┆            ┆            ┆            │
# │ P005       ┆ 5001    ┆ angers ┆ 2016-08-19  ┆ 2016-08-24  ┆ 0          ┆ 0          ┆ C349       │
# │            ┆         ┆        ┆ 11:00:00    ┆ 10:00:00    ┆            ┆            ┆            │
# │ P006       ┆ 6001    ┆ brest  ┆ 2017-05-06  ┆ 2017-05-12  ┆ 0          ┆ 0          ┆ null       │
# │            ┆         ┆        ┆ 09:20:00    ┆ 11:30:00    ┆            ┆            ┆            │
# │ P008       ┆ 8001    ┆ tours  ┆ 2017-09-10  ┆ 2017-09-16  ┆ 0          ┆ 0          ┆ I693       │
# │            ┆         ┆        ┆ 13:00:00    ┆ 09:30:00    ┆            ┆            ┆            │
# │ P009       ┆ 9001    ┆ angers ┆ 2014-12-03  ┆ 2014-12-09  ┆ 0          ┆ 0          ┆ null       │
# │            ┆         ┆        ┆ 10:15:00    ┆ 14:20:00    ┆            ┆            ┆            │
# │ P010       ┆ 10001   ┆ brest  ┆ 2015-04-18  ┆ 2015-04-23  ┆ 0          ┆ 0          ┆ I48        │
# │            ┆         ┆        ┆ 12:20:00    ┆ 10:00:00    ┆            ┆            ┆            │
# └────────────┴─────────┴────────┴─────────────┴─────────────┴────────────┴────────────┴────────────┘

# %%
disease_dict = comorbidity_utils.load_disease_dict('cim10_nancy.json')

# %%
comorbidities = comorbidity_utils.get_comorbidities(
    preceding_hosps_of_included_patients_with_cim10,
    disease_dict
)

# %%
comorbidities.sort("patient_id")
# Out:
# shape: (9, 19)
# ┌────────────┬─────────┬────────┬──────────────┬───┬────────┬──────────────┬─────────────┬─────────┐
# │ patient_id ┆ hosp_id ┆ centre ┆ inclusion_fl ┆ … ┆ Cancer ┆ Immunodépres ┆ Dyslipidémi ┆ Diabète │
# │ ---        ┆ ---     ┆ ---    ┆ ag           ┆   ┆ actif  ┆ sion         ┆ e           ┆ ---     │
# │ str        ┆ i64     ┆ str    ┆ ---          ┆   ┆ ---    ┆ ---          ┆ ---         ┆ i32     │
# │            ┆         ┆        ┆ i64          ┆   ┆ i32    ┆ i32          ┆ i32         ┆         │
# ╞════════════╪═════════╪════════╪══════════════╪═══╪════════╪══════════════╪═════════════╪═════════╡
# │ P001       ┆ 1001    ┆ angers ┆ 0            ┆ … ┆ 0      ┆ 0            ┆ 0           ┆ 0       │
# │ P002       ┆ 2001    ┆ brest  ┆ 0            ┆ … ┆ 0      ┆ 0            ┆ 0           ┆ 1       │
# │ P003       ┆ 3001    ┆ nantes ┆ 0            ┆ … ┆ 0      ┆ 0            ┆ 0           ┆ 0       │
# │ P004       ┆ 4001    ┆ tours  ┆ 0            ┆ … ┆ 0      ┆ 0            ┆ 0           ┆ 0       │
# │ P005       ┆ 5001    ┆ angers ┆ 0            ┆ … ┆ 1      ┆ 0            ┆ 1           ┆ 0       │
# │ P006       ┆ 6001    ┆ brest  ┆ 0            ┆ … ┆ 0      ┆ 0            ┆ 0           ┆ 0       │
# │ P008       ┆ 8001    ┆ tours  ┆ 0            ┆ … ┆ 0      ┆ 0            ┆ 0           ┆ 0       │
# │ P009       ┆ 9001    ┆ angers ┆ 0            ┆ … ┆ 0      ┆ 0            ┆ 0           ┆ 0       │
# │ P010       ┆ 10001   ┆ brest  ┆ 0            ┆ … ┆ 0      ┆ 0            ┆ 0           ┆ 0       │
# └────────────┴─────────┴────────┴──────────────┴───┴────────┴──────────────┴─────────────┴─────────┘

# %%
patient_comorbidities = comorbidity_utils.get_patient_comorbidities(comorbidities)

# %%
patient_comorbidities.sort("patient_id")
# Out:
# shape: (9, 13)
# ┌────────────┬────────────┬────────────┬────────────┬───┬────────┬───────────┬───────────┬─────────┐
# │ patient_id ┆ Cardiopath ┆ Fibrillati ┆ Insuffisan ┆ … ┆ Cancer ┆ Immunodép ┆ Dyslipidé ┆ Diabète │
# │ ---        ┆ ie         ┆ on atriale ┆ ce         ┆   ┆ actif  ┆ ression   ┆ mie       ┆ ---     │
# │ str        ┆ ischémique ┆ ---        ┆ cardiaque  ┆   ┆ ---    ┆ ---       ┆ ---       ┆ i32     │
# │            ┆ ---        ┆ i32        ┆ chroniq…   ┆   ┆ i32    ┆ i32       ┆ i32       ┆         │
# │            ┆ i32        ┆            ┆ ---        ┆   ┆        ┆           ┆           ┆         │
# │            ┆            ┆            ┆ i32        ┆   ┆        ┆           ┆           ┆         │
# ╞════════════╪════════════╪════════════╪════════════╪═══╪════════╪═══════════╪═══════════╪═════════╡
# │ P001       ┆ 1          ┆ 1          ┆ 0          ┆ … ┆ 0      ┆ 0         ┆ 0         ┆ 0       │
# │ P002       ┆ 0          ┆ 0          ┆ 0          ┆ … ┆ 0      ┆ 0         ┆ 0         ┆ 1       │
# │ P003       ┆ 0          ┆ 0          ┆ 1          ┆ … ┆ 0      ┆ 0         ┆ 0         ┆ 0       │
# │ P004       ┆ 1          ┆ 0          ┆ 0          ┆ … ┆ 0      ┆ 0         ┆ 0         ┆ 0       │
# │ P005       ┆ 0          ┆ 0          ┆ 0          ┆ … ┆ 1      ┆ 0         ┆ 1         ┆ 0       │
# │ P006       ┆ 0          ┆ 0          ┆ 0          ┆ … ┆ 0      ┆ 0         ┆ 0         ┆ 0       │
# │ P008       ┆ 0          ┆ 0          ┆ 0          ┆ … ┆ 0      ┆ 0         ┆ 0         ┆ 0       │
# │ P009       ┆ 0          ┆ 0          ┆ 0          ┆ … ┆ 0      ┆ 0         ┆ 0         ┆ 0       │
# │ P010       ┆ 0          ┆ 1          ┆ 0          ┆ … ┆ 0      ┆ 0         ┆ 0         ┆ 0       │
# └────────────┴────────────┴────────────┴────────────┴───┴────────┴───────────┴───────────┴─────────┘

# %%
disease_cols = ["Cardiopathie ischémique", "Fibrillation atriale", "Insuffisance cardiaque chronique",
               "Pacemaker", "Pontage aorto-coronarien", "Insuffisance rénale chronique", "Antécédent d'AVC",
               "Cirrhose", "Cancer actif", "Immunodépression", "Dyslipidémie", "Diabète"]

# %%
included_patients_with_comorbidity =comorbidity_utils.get_included_patients_with_comorbidity(
    first_inclusion_hosps,
    patient_comorbidities,
    disease_cols
)

# %%
pl.Config.set_tbl_rows(-1)

included_patients_with_comorbidity
# Out:
# shape: (10, 19)
# ┌────────────┬─────────┬────────┬──────────────┬───┬────────┬──────────────┬─────────────┬─────────┐
# │ patient_id ┆ hosp_id ┆ centre ┆ hosp_admissi ┆ … ┆ Cancer ┆ Immunodépres ┆ Dyslipidémi ┆ Diabète │
# │ ---        ┆ ---     ┆ ---    ┆ on_datetime  ┆   ┆ actif  ┆ sion         ┆ e           ┆ ---     │
# │ str        ┆ i64     ┆ str    ┆ ---          ┆   ┆ ---    ┆ ---          ┆ ---         ┆ i8      │
# │            ┆         ┆        ┆ datetime[μs] ┆   ┆ i8     ┆ i8           ┆ i8          ┆         │
# ╞════════════╪═════════╪════════╪══════════════╪═══╪════════╪══════════════╪═════════════╪═════════╡
# │ P001       ┆ 1002    ┆ angers ┆ 2018-07-04   ┆ … ┆ 0      ┆ 0            ┆ 0           ┆ 0       │
# │            ┆         ┆        ┆ 11:15:00     ┆   ┆        ┆              ┆             ┆         │
# │ P002       ┆ 2002    ┆ brest  ┆ 2019-01-18   ┆ … ┆ 0      ┆ 0            ┆ 0           ┆ 1       │
# │            ┆         ┆        ┆ 13:20:00     ┆   ┆        ┆              ┆             ┆         │
# │ P003       ┆ 3002    ┆ nantes ┆ 2019-04-09   ┆ … ┆ 0      ┆ 0            ┆ 0           ┆ 0       │
# │            ┆         ┆        ┆ 09:15:00     ┆   ┆        ┆              ┆             ┆         │
# │ P004       ┆ 4002    ┆ tours  ┆ 2018-03-03   ┆ … ┆ 0      ┆ 0            ┆ 0           ┆ 0       │
# │            ┆         ┆        ┆ 07:50:00     ┆   ┆        ┆              ┆             ┆         │
# │ P005       ┆ 5002    ┆ angers ┆ 2019-02-01   ┆ … ┆ 1      ┆ 0            ┆ 1           ┆ 0       │
# │            ┆         ┆        ┆ 14:10:00     ┆   ┆        ┆              ┆             ┆         │
# │ P006       ┆ 6002    ┆ brest  ┆ 2020-06-17   ┆ … ┆ 0      ┆ 0            ┆ 0           ┆ 0       │
# │            ┆         ┆        ┆ 10:45:00     ┆   ┆        ┆              ┆             ┆         │
# │ P007       ┆ 7001    ┆ nantes ┆ 2020-07-22   ┆ … ┆ 0      ┆ 0            ┆ 0           ┆ 0       │
# │            ┆         ┆        ┆ 08:30:00     ┆   ┆        ┆              ┆             ┆         │
# │ P008       ┆ 8002    ┆ tours  ┆ 2020-12-05   ┆ … ┆ 0      ┆ 0            ┆ 0           ┆ 0       │
# │            ┆         ┆        ┆ 06:45:00     ┆   ┆        ┆              ┆             ┆         │
# │ P009       ┆ 9002    ┆ angers ┆ 2017-01-26   ┆ … ┆ 0      ┆ 0            ┆ 0           ┆ 0       │
# │            ┆         ┆        ┆ 09:00:00     ┆   ┆        ┆              ┆             ┆         │
# │ P010       ┆ 10002   ┆ brest  ┆ 2020-03-21   ┆ … ┆ 0      ┆ 0            ┆ 0           ┆ 0       │
# │            ┆         ┆        ┆ 16:30:00     ┆   ┆        ┆              ┆             ┆         │
# └────────────┴─────────┴────────┴──────────────┴───┴────────┴──────────────┴─────────────┴─────────┘

# %%
treatments
# Out:
# shape: (13, 12)
# ┌────────┬────────────┬─────────┬────────────┬───┬─────────────┬────────────┬───────────┬──────────┐
# │ ent_id ┆ context_id ┆ text_id ┆ patient_id ┆ … ┆ dose        ┆ frequency  ┆ ent_start ┆ ent_end  │
# │ ---    ┆ ---        ┆ ---     ┆ ---        ┆   ┆ ---         ┆ ---        ┆ ---       ┆ ---      │
# │ str    ┆ str        ┆ str     ┆ str        ┆   ┆ list[str]   ┆ list[str]  ┆ i64       ┆ i64      │
# ╞════════╪════════════╪═════════╪════════════╪═══╪═════════════╪════════════╪═══════════╪══════════╡
# │ D001   ┆ 1001       ┆ TXT001  ┆ P001       ┆ … ┆ ["2.5 mg"]  ┆ ["1 fois/j ┆ 20150310  ┆ 20150316 │
# │        ┆            ┆         ┆            ┆   ┆             ┆ our"]      ┆           ┆          │
# │ D002   ┆ 1001       ┆ TXT001  ┆ P001       ┆ … ┆ ["5 mg"]    ┆ ["1 fois/j ┆ 20150310  ┆ 20150316 │
# │        ┆            ┆         ┆            ┆   ┆             ┆ our"]      ┆           ┆          │
# │ D003   ┆ 2001       ┆ TXT002  ┆ P002       ┆ … ┆ ["500 mg"]  ┆ ["2 fois/j ┆ 20140622  ┆ 20140628 │
# │        ┆            ┆         ┆            ┆   ┆             ┆ our"]      ┆           ┆          │
# │ D004   ┆ 3001       ┆ TXT003  ┆ P003       ┆ … ┆ ["1.25 mg"] ┆ ["1 fois/j ┆ 20160205  ┆ 20160211 │
# │        ┆            ┆         ┆            ┆   ┆             ┆ our"]      ┆           ┆          │
# │ D005   ┆ 3001       ┆ TXT003  ┆ P003       ┆ … ┆ ["40 mg"]   ┆ ["1 fois/j ┆ 20160205  ┆ 20160211 │
# │        ┆            ┆         ┆            ┆   ┆             ┆ our"]      ┆           ┆          │
# │ D006   ┆ 3001       ┆ TXT003  ┆ P003       ┆ … ┆ ["25 mg"]   ┆ ["1 fois/j ┆ 20160205  ┆ 20160211 │
# │        ┆            ┆         ┆            ┆   ┆             ┆ our"]      ┆           ┆          │
# │ D007   ┆ 4001       ┆ TXT004  ┆ P004       ┆ … ┆ ["2.5 mg"]  ┆ ["1 fois/j ┆ 20151114  ┆ 20151120 │
# │        ┆            ┆         ┆            ┆   ┆             ┆ our"]      ┆           ┆          │
# │ D008   ┆ 4002       ┆ TXT005  ┆ P004       ┆ … ┆ ["24/26     ┆ ["2 fois/j ┆ 20180303  ┆ 20180318 │
# │        ┆            ┆         ┆            ┆   ┆ mg"]        ┆ our"]      ┆           ┆          │
# │ D009   ┆ 4002       ┆ TXT005  ┆ P004       ┆ … ┆ ["10 mg"]   ┆ ["1 fois/j ┆ 20180303  ┆ 20180318 │
# │        ┆            ┆         ┆            ┆   ┆             ┆ our"]      ┆           ┆          │
# │ D010   ┆ 6002       ┆ TXT006  ┆ P006       ┆ … ┆ ["1 g"]     ┆ ["si       ┆ 20200617  ┆ 20200624 │
# │        ┆            ┆         ┆            ┆   ┆             ┆ besoin"]   ┆           ┆          │
# │ D011   ┆ 8001       ┆ TXT007  ┆ P008       ┆ … ┆ ["20 mg"]   ┆ ["1 fois/j ┆ 20170910  ┆ 20170916 │
# │        ┆            ┆         ┆            ┆   ┆             ┆ our"]      ┆           ┆          │
# │ D012   ┆ 8002       ┆ TXT008  ┆ P008       ┆ … ┆ ["5 mg"]    ┆ ["2 fois/j ┆ 20201205  ┆ 20201220 │
# │        ┆            ┆         ┆            ┆   ┆             ┆ our"]      ┆           ┆          │
# │ D013   ┆ 10001      ┆ TXT009  ┆ P010       ┆ … ┆ ["200 mg"]  ┆ ["1 fois/j ┆ 20150418  ┆ 20150423 │
# │        ┆            ┆         ┆            ┆   ┆             ┆ our"]      ┆           ┆          │
# └────────┴────────────┴─────────┴────────────┴───┴─────────────┴────────────┴───────────┴──────────┘

# %%
treatments = treatments.rename({
    "frequency": "frequency/duration"
})

# %%
treatments
# Out:
# shape: (13, 12)
# ┌────────┬────────────┬─────────┬────────────┬───┬─────────────┬────────────┬───────────┬──────────┐
# │ ent_id ┆ context_id ┆ text_id ┆ patient_id ┆ … ┆ dose        ┆ frequency/ ┆ ent_start ┆ ent_end  │
# │ ---    ┆ ---        ┆ ---     ┆ ---        ┆   ┆ ---         ┆ duration   ┆ ---       ┆ ---      │
# │ str    ┆ str        ┆ str     ┆ str        ┆   ┆ list[str]   ┆ ---        ┆ i64       ┆ i64      │
# │        ┆            ┆         ┆            ┆   ┆             ┆ list[str]  ┆           ┆          │
# ╞════════╪════════════╪═════════╪════════════╪═══╪═════════════╪════════════╪═══════════╪══════════╡
# │ D001   ┆ 1001       ┆ TXT001  ┆ P001       ┆ … ┆ ["2.5 mg"]  ┆ ["1 fois/j ┆ 20150310  ┆ 20150316 │
# │        ┆            ┆         ┆            ┆   ┆             ┆ our"]      ┆           ┆          │
# │ D002   ┆ 1001       ┆ TXT001  ┆ P001       ┆ … ┆ ["5 mg"]    ┆ ["1 fois/j ┆ 20150310  ┆ 20150316 │
# │        ┆            ┆         ┆            ┆   ┆             ┆ our"]      ┆           ┆          │
# │ D003   ┆ 2001       ┆ TXT002  ┆ P002       ┆ … ┆ ["500 mg"]  ┆ ["2 fois/j ┆ 20140622  ┆ 20140628 │
# │        ┆            ┆         ┆            ┆   ┆             ┆ our"]      ┆           ┆          │
# │ D004   ┆ 3001       ┆ TXT003  ┆ P003       ┆ … ┆ ["1.25 mg"] ┆ ["1 fois/j ┆ 20160205  ┆ 20160211 │
# │        ┆            ┆         ┆            ┆   ┆             ┆ our"]      ┆           ┆          │
# │ D005   ┆ 3001       ┆ TXT003  ┆ P003       ┆ … ┆ ["40 mg"]   ┆ ["1 fois/j ┆ 20160205  ┆ 20160211 │
# │        ┆            ┆         ┆            ┆   ┆             ┆ our"]      ┆           ┆          │
# │ D006   ┆ 3001       ┆ TXT003  ┆ P003       ┆ … ┆ ["25 mg"]   ┆ ["1 fois/j ┆ 20160205  ┆ 20160211 │
# │        ┆            ┆         ┆            ┆   ┆             ┆ our"]      ┆           ┆          │
# │ D007   ┆ 4001       ┆ TXT004  ┆ P004       ┆ … ┆ ["2.5 mg"]  ┆ ["1 fois/j ┆ 20151114  ┆ 20151120 │
# │        ┆            ┆         ┆            ┆   ┆             ┆ our"]      ┆           ┆          │
# │ D008   ┆ 4002       ┆ TXT005  ┆ P004       ┆ … ┆ ["24/26     ┆ ["2 fois/j ┆ 20180303  ┆ 20180318 │
# │        ┆            ┆         ┆            ┆   ┆ mg"]        ┆ our"]      ┆           ┆          │
# │ D009   ┆ 4002       ┆ TXT005  ┆ P004       ┆ … ┆ ["10 mg"]   ┆ ["1 fois/j ┆ 20180303  ┆ 20180318 │
# │        ┆            ┆         ┆            ┆   ┆             ┆ our"]      ┆           ┆          │
# │ D010   ┆ 6002       ┆ TXT006  ┆ P006       ┆ … ┆ ["1 g"]     ┆ ["si       ┆ 20200617  ┆ 20200624 │
# │        ┆            ┆         ┆            ┆   ┆             ┆ besoin"]   ┆           ┆          │
# │ D011   ┆ 8001       ┆ TXT007  ┆ P008       ┆ … ┆ ["20 mg"]   ┆ ["1 fois/j ┆ 20170910  ┆ 20170916 │
# │        ┆            ┆         ┆            ┆   ┆             ┆ our"]      ┆           ┆          │
# │ D012   ┆ 8002       ┆ TXT008  ┆ P008       ┆ … ┆ ["5 mg"]    ┆ ["2 fois/j ┆ 20201205  ┆ 20201220 │
# │        ┆            ┆         ┆            ┆   ┆             ┆ our"]      ┆           ┆          │
# │ D013   ┆ 10001      ┆ TXT009  ┆ P010       ┆ … ┆ ["200 mg"]  ┆ ["1 fois/j ┆ 20150418  ┆ 20150423 │
# │        ┆            ┆         ┆            ┆   ┆             ┆ our"]      ┆           ┆          │
# └────────┴────────────┴─────────┴────────────┴───┴─────────────┴────────────┴───────────┴──────────┘

# %%
treatments_with_flags = drug.create_treatment_flags(treatments)

# %%
pl.Config.set_tbl_rows(-1)
treatments_with_flags
# Out:
# shape: (13, 13)
# ┌────────────┬─────────┬───────────────┬──────────┬───┬──────┬───────────────┬────────┬────────────┐
# │ patient_id ┆ text_id ┆ ent_name      ┆ code_atc ┆ … ┆ ARNI ┆ anti_aldoster ┆ sglt2i ┆ furosemide │
# │ ---        ┆ ---     ┆ ---           ┆ ---      ┆   ┆ ---  ┆ one           ┆ ---    ┆ ---        │
# │ str        ┆ str     ┆ str           ┆ str      ┆   ┆ i8   ┆ ---           ┆ i8     ┆ i8         │
# │            ┆         ┆               ┆          ┆   ┆      ┆ i8            ┆        ┆            │
# ╞════════════╪═════════╪═══════════════╪══════════╪═══╪══════╪═══════════════╪════════╪════════════╡
# │ P001       ┆ TXT001  ┆ bisoprolol    ┆ C07AB07  ┆ … ┆ 0    ┆ 0             ┆ 0      ┆ 0          │
# │ P001       ┆ TXT001  ┆ ramipril      ┆ C09AA05  ┆ … ┆ 0    ┆ 0             ┆ 0      ┆ 0          │
# │ P002       ┆ TXT002  ┆ metformine    ┆ A10BA02  ┆ … ┆ 0    ┆ 0             ┆ 1      ┆ 0          │
# │ P003       ┆ TXT003  ┆ bisoprolol    ┆ C07AB07  ┆ … ┆ 0    ┆ 0             ┆ 0      ┆ 0          │
# │ P003       ┆ TXT003  ┆ furosémide    ┆ C03CA01  ┆ … ┆ 0    ┆ 1             ┆ 0      ┆ 1          │
# │ P003       ┆ TXT003  ┆ spironolacton ┆ C03DA01  ┆ … ┆ 0    ┆ 1             ┆ 0      ┆ 0          │
# │            ┆         ┆ e             ┆          ┆   ┆      ┆               ┆        ┆            │
# │ P004       ┆ TXT004  ┆ bisoprolol    ┆ C07AB07  ┆ … ┆ 0    ┆ 0             ┆ 0      ┆ 0          │
# │ P004       ┆ TXT005  ┆ sacubitril    ┆ C09DX04  ┆ … ┆ 1    ┆ 0             ┆ 0      ┆ 0          │
# │            ┆         ┆ valsartan     ┆          ┆   ┆      ┆               ┆        ┆            │
# │ P004       ┆ TXT005  ┆ dapagliflozin ┆ A10BK01  ┆ … ┆ 0    ┆ 0             ┆ 1      ┆ 0          │
# │            ┆         ┆ e             ┆          ┆   ┆      ┆               ┆        ┆            │
# │ P006       ┆ TXT006  ┆ paracétamol   ┆ N02BE01  ┆ … ┆ 0    ┆ 0             ┆ 0      ┆ 0          │
# │ P008       ┆ TXT007  ┆ atorvastatine ┆ C10AA05  ┆ … ┆ 0    ┆ 0             ┆ 0      ┆ 0          │
# │ P008       ┆ TXT008  ┆ apixaban      ┆ B01AF02  ┆ … ┆ 0    ┆ 0             ┆ 0      ┆ 0          │
# │ P010       ┆ TXT009  ┆ amiodarone    ┆ C01BD01  ┆ … ┆ 0    ┆ 0             ┆ 0      ┆ 0          │
# └────────────┴─────────┴───────────────┴──────────┴───┴──────┴───────────────┴────────┴────────────┘

# %%
patient_treatment_flags = drug.get_patient_treatment_flags(treatments_with_flags)

# %%
pl.Config.set_tbl_rows(-1)
patient_treatment_flags
# Out:
# shape: (7, 8)
# ┌────────────┬──────────────┬──────┬─────┬──────┬──────────────────┬────────┬────────────┐
# │ patient_id ┆ beta_blocker ┆ ACEI ┆ ARB ┆ ARNI ┆ anti_aldosterone ┆ sglt2i ┆ furosemide │
# │ ---        ┆ ---          ┆ ---  ┆ --- ┆ ---  ┆ ---              ┆ ---    ┆ ---        │
# │ str        ┆ i8           ┆ i8   ┆ i8  ┆ i8   ┆ i8               ┆ i8     ┆ i8         │
# ╞════════════╪══════════════╪══════╪═════╪══════╪══════════════════╪════════╪════════════╡
# │ P001       ┆ 1            ┆ 1    ┆ 0   ┆ 0    ┆ 0                ┆ 0      ┆ 0          │
# │ P002       ┆ 0            ┆ 0    ┆ 0   ┆ 0    ┆ 0                ┆ 1      ┆ 0          │
# │ P003       ┆ 1            ┆ 0    ┆ 0   ┆ 0    ┆ 1                ┆ 0      ┆ 1          │
# │ P004       ┆ 1            ┆ 0    ┆ 0   ┆ 1    ┆ 0                ┆ 1      ┆ 0          │
# │ P006       ┆ 0            ┆ 0    ┆ 0   ┆ 0    ┆ 0                ┆ 0      ┆ 0          │
# │ P008       ┆ 0            ┆ 0    ┆ 0   ┆ 0    ┆ 0                ┆ 0      ┆ 0          │
# │ P010       ┆ 0            ┆ 0    ┆ 0   ┆ 0    ┆ 0                ┆ 0      ┆ 0          │
# └────────────┴──────────────┴──────┴─────┴──────┴──────────────────┴────────┴────────────┘

# %%
drug_cols = ["beta_blocker", "ACEI", "ARB", "ARNI", "anti_aldosterone", "sglt2i", "furosemide"]

# %%
included_patient_with_comorbidity_drug = drug.get_patient_with_comorbidity_drug(
    included_patients_with_comorbidity,
    patient_treatment_flags,
    drug_cols
)

# %%
pl.Config.set_tbl_rows(-1)
included_patient_with_comorbidity_drug
# Out:
# shape: (10, 26)
# ┌────────────┬─────────┬────────┬────────────────┬───┬──────┬────────────────┬────────┬────────────┐
# │ patient_id ┆ hosp_id ┆ centre ┆ hosp_admission ┆ … ┆ ARNI ┆ anti_aldostero ┆ sglt2i ┆ furosemide │
# │ ---        ┆ ---     ┆ ---    ┆ _datetime      ┆   ┆ ---  ┆ ne             ┆ ---    ┆ ---        │
# │ str        ┆ i64     ┆ str    ┆ ---            ┆   ┆ i8   ┆ ---            ┆ i8     ┆ i8         │
# │            ┆         ┆        ┆ datetime[μs]   ┆   ┆      ┆ i8             ┆        ┆            │
# ╞════════════╪═════════╪════════╪════════════════╪═══╪══════╪════════════════╪════════╪════════════╡
# │ P001       ┆ 1002    ┆ angers ┆ 2018-07-04     ┆ … ┆ 0    ┆ 0              ┆ 0      ┆ 0          │
# │            ┆         ┆        ┆ 11:15:00       ┆   ┆      ┆                ┆        ┆            │
# │ P002       ┆ 2002    ┆ brest  ┆ 2019-01-18     ┆ … ┆ 0    ┆ 0              ┆ 1      ┆ 0          │
# │            ┆         ┆        ┆ 13:20:00       ┆   ┆      ┆                ┆        ┆            │
# │ P003       ┆ 3002    ┆ nantes ┆ 2019-04-09     ┆ … ┆ 0    ┆ 1              ┆ 0      ┆ 1          │
# │            ┆         ┆        ┆ 09:15:00       ┆   ┆      ┆                ┆        ┆            │
# │ P004       ┆ 4002    ┆ tours  ┆ 2018-03-03     ┆ … ┆ 1    ┆ 0              ┆ 1      ┆ 0          │
# │            ┆         ┆        ┆ 07:50:00       ┆   ┆      ┆                ┆        ┆            │
# │ P005       ┆ 5002    ┆ angers ┆ 2019-02-01     ┆ … ┆ 0    ┆ 0              ┆ 0      ┆ 0          │
# │            ┆         ┆        ┆ 14:10:00       ┆   ┆      ┆                ┆        ┆            │
# │ P006       ┆ 6002    ┆ brest  ┆ 2020-06-17     ┆ … ┆ 0    ┆ 0              ┆ 0      ┆ 0          │
# │            ┆         ┆        ┆ 10:45:00       ┆   ┆      ┆                ┆        ┆            │
# │ P007       ┆ 7001    ┆ nantes ┆ 2020-07-22     ┆ … ┆ 0    ┆ 0              ┆ 0      ┆ 0          │
# │            ┆         ┆        ┆ 08:30:00       ┆   ┆      ┆                ┆        ┆            │
# │ P008       ┆ 8002    ┆ tours  ┆ 2020-12-05     ┆ … ┆ 0    ┆ 0              ┆ 0      ┆ 0          │
# │            ┆         ┆        ┆ 06:45:00       ┆   ┆      ┆                ┆        ┆            │
# │ P009       ┆ 9002    ┆ angers ┆ 2017-01-26     ┆ … ┆ 0    ┆ 0              ┆ 0      ┆ 0          │
# │            ┆         ┆        ┆ 09:00:00       ┆   ┆      ┆                ┆        ┆            │
# │ P010       ┆ 10002   ┆ brest  ┆ 2020-03-21     ┆ … ┆ 0    ┆ 0              ┆ 0      ┆ 0          │
# │            ┆         ┆        ┆ 16:30:00       ┆   ┆      ┆                ┆        ┆            │
# └────────────┴─────────┴────────┴────────────────┴───┴──────┴────────────────┴────────┴────────────┘

# %%
patients_with_death_date = patient_utils.get_patients_with_death_date(patient)

# %%
patients_with_death_date
# Out:
# shape: (10, 4)
# ┌────────────┬────────┬────────────┬────────────┐
# │ patient_id ┆ gender ┆ birth_date ┆ death_date │
# │ ---        ┆ ---    ┆ ---        ┆ ---        │
# │ str        ┆ str    ┆ date       ┆ date       │
# ╞════════════╪════════╪════════════╪════════════╡
# │ P001       ┆ F      ┆ 1933-04-12 ┆ 2018-09-21 │
# │ P002       ┆ M      ┆ 1934-11-03 ┆ null       │
# │ P003       ┆ F      ┆ 1935-07-26 ┆ 2020-12-04 │
# │ P004       ┆ M      ┆ 1936-02-18 ┆ null       │
# │ P005       ┆ F      ┆ 1937-09-09 ┆ 2019-03-17 │
# │ P006       ┆ M      ┆ 1938-12-22 ┆ null       │
# │ P007       ┆ F      ┆ 1939-05-15 ┆ null       │
# │ P008       ┆ M      ┆ 1940-01-30 ┆ 2021-07-02 │
# │ P009       ┆ F      ┆ 1933-10-05 ┆ null       │
# │ P010       ┆ M      ┆ 1936-06-28 ┆ 2020-04-11 │
# └────────────┴────────┴────────────┴────────────┘

# %%
included_patient_with_comorbidity_drug_demo = included_patient_with_comorbidity_drug.join(patients_with_death_date, how = "left", on = "patient_id")

# %%
included_patient_with_comorbidity_drug_demo
# Out:
# shape: (10, 29)
# ┌────────────┬─────────┬────────┬──────────────┬───┬────────────┬────────┬────────────┬────────────┐
# │ patient_id ┆ hosp_id ┆ centre ┆ hosp_admissi ┆ … ┆ furosemide ┆ gender ┆ birth_date ┆ death_date │
# │ ---        ┆ ---     ┆ ---    ┆ on_datetime  ┆   ┆ ---        ┆ ---    ┆ ---        ┆ ---        │
# │ str        ┆ i64     ┆ str    ┆ ---          ┆   ┆ i8         ┆ str    ┆ date       ┆ date       │
# │            ┆         ┆        ┆ datetime[μs] ┆   ┆            ┆        ┆            ┆            │
# ╞════════════╪═════════╪════════╪══════════════╪═══╪════════════╪════════╪════════════╪════════════╡
# │ P001       ┆ 1002    ┆ angers ┆ 2018-07-04   ┆ … ┆ 0          ┆ F      ┆ 1933-04-12 ┆ 2018-09-21 │
# │            ┆         ┆        ┆ 11:15:00     ┆   ┆            ┆        ┆            ┆            │
# │ P002       ┆ 2002    ┆ brest  ┆ 2019-01-18   ┆ … ┆ 0          ┆ M      ┆ 1934-11-03 ┆ null       │
# │            ┆         ┆        ┆ 13:20:00     ┆   ┆            ┆        ┆            ┆            │
# │ P003       ┆ 3002    ┆ nantes ┆ 2019-04-09   ┆ … ┆ 1          ┆ F      ┆ 1935-07-26 ┆ 2020-12-04 │
# │            ┆         ┆        ┆ 09:15:00     ┆   ┆            ┆        ┆            ┆            │
# │ P004       ┆ 4002    ┆ tours  ┆ 2018-03-03   ┆ … ┆ 0          ┆ M      ┆ 1936-02-18 ┆ null       │
# │            ┆         ┆        ┆ 07:50:00     ┆   ┆            ┆        ┆            ┆            │
# │ P005       ┆ 5002    ┆ angers ┆ 2019-02-01   ┆ … ┆ 0          ┆ F      ┆ 1937-09-09 ┆ 2019-03-17 │
# │            ┆         ┆        ┆ 14:10:00     ┆   ┆            ┆        ┆            ┆            │
# │ P006       ┆ 6002    ┆ brest  ┆ 2020-06-17   ┆ … ┆ 0          ┆ M      ┆ 1938-12-22 ┆ null       │
# │            ┆         ┆        ┆ 10:45:00     ┆   ┆            ┆        ┆            ┆            │
# │ P007       ┆ 7001    ┆ nantes ┆ 2020-07-22   ┆ … ┆ 0          ┆ F      ┆ 1939-05-15 ┆ null       │
# │            ┆         ┆        ┆ 08:30:00     ┆   ┆            ┆        ┆            ┆            │
# │ P008       ┆ 8002    ┆ tours  ┆ 2020-12-05   ┆ … ┆ 0          ┆ M      ┆ 1940-01-30 ┆ 2021-07-02 │
# │            ┆         ┆        ┆ 06:45:00     ┆   ┆            ┆        ┆            ┆            │
# │ P009       ┆ 9002    ┆ angers ┆ 2017-01-26   ┆ … ┆ 0          ┆ F      ┆ 1933-10-05 ┆ null       │
# │            ┆         ┆        ┆ 09:00:00     ┆   ┆            ┆        ┆            ┆            │
# │ P010       ┆ 10002   ┆ brest  ┆ 2020-03-21   ┆ … ┆ 0          ┆ M      ┆ 1936-06-28 ┆ 2020-04-11 │
# │            ┆         ┆        ┆ 16:30:00     ┆   ┆            ┆        ┆            ┆            │
# └────────────┴─────────┴────────┴──────────────┴───┴────────────┴────────┴────────────┴────────────┘

# %%
included_patient_with_comorbidity_drug_demo = patient_utils.age_at_admission(included_patient_with_comorbidity_drug_demo)

# %%
included_patient_with_comorbidity_drug_demo.select("patient_id", "age_at_admission")
# Out:
# shape: (10, 2)
# ┌────────────┬──────────────────┐
# │ patient_id ┆ age_at_admission │
# │ ---        ┆ ---              │
# │ str        ┆ i32              │
# ╞════════════╪══════════════════╡
# │ P001       ┆ 85               │
# │ P002       ┆ 84               │
# │ P003       ┆ 83               │
# │ P004       ┆ 82               │
# │ P005       ┆ 81               │
# │ P006       ┆ 81               │
# │ P007       ┆ 81               │
# │ P008       ┆ 80               │
# │ P009       ┆ 83               │
# │ P010       ┆ 83               │
# └────────────┴──────────────────┘

# %%
preceding_hosps_of_included_patients_with_cim10
# Out:
# shape: (12, 8)
# ┌────────────┬─────────┬────────┬─────────────┬─────────────┬────────────┬────────────┬────────────┐
# │ patient_id ┆ hosp_id ┆ centre ┆ hosp_admiss ┆ hosp_discha ┆ inclusion_ ┆ icu_stay_f ┆ concept_co │
# │ ---        ┆ ---     ┆ ---    ┆ ion_datetim ┆ rge_datetim ┆ flag       ┆ lag        ┆ de         │
# │ str        ┆ i64     ┆ str    ┆ e           ┆ e           ┆ ---        ┆ ---        ┆ ---        │
# │            ┆         ┆        ┆ ---         ┆ ---         ┆ i64        ┆ i8         ┆ str        │
# │            ┆         ┆        ┆ datetime[μs ┆ datetime[μs ┆            ┆            ┆            │
# │            ┆         ┆        ┆ ]           ┆ ]           ┆            ┆            ┆            │
# ╞════════════╪═════════╪════════╪═════════════╪═════════════╪════════════╪════════════╪════════════╡
# │ P001       ┆ 1001    ┆ angers ┆ 2015-03-10  ┆ 2015-03-16  ┆ 0          ┆ 0          ┆ I48        │
# │            ┆         ┆        ┆ 09:30:00    ┆ 14:00:00    ┆            ┆            ┆            │
# │ P001       ┆ 1001    ┆ angers ┆ 2015-03-10  ┆ 2015-03-16  ┆ 0          ┆ 0          ┆ I25        │
# │            ┆         ┆        ┆ 09:30:00    ┆ 14:00:00    ┆            ┆            ┆            │
# │ P002       ┆ 2001    ┆ brest  ┆ 2014-06-22  ┆ 2014-06-28  ┆ 0          ┆ 0          ┆ E119       │
# │            ┆         ┆        ┆ 08:40:00    ┆ 15:30:00    ┆            ┆            ┆            │
# │ P003       ┆ 3001    ┆ nantes ┆ 2016-02-05  ┆ 2016-02-11  ┆ 0          ┆ 0          ┆ N18        │
# │            ┆         ┆        ┆ 10:00:00    ┆ 16:00:00    ┆            ┆            ┆            │
# │ P003       ┆ 3001    ┆ nantes ┆ 2016-02-05  ┆ 2016-02-11  ┆ 0          ┆ 0          ┆ I50        │
# │            ┆         ┆        ┆ 10:00:00    ┆ 16:00:00    ┆            ┆            ┆            │
# │ P004       ┆ 4001    ┆ tours  ┆ 2015-11-14  ┆ 2015-11-20  ┆ 0          ┆ 0          ┆ I21        │
# │            ┆         ┆        ┆ 15:00:00    ┆ 13:00:00    ┆            ┆            ┆            │
# │ P005       ┆ 5001    ┆ angers ┆ 2016-08-19  ┆ 2016-08-24  ┆ 0          ┆ 0          ┆ E785       │
# │            ┆         ┆        ┆ 11:00:00    ┆ 10:00:00    ┆            ┆            ┆            │
# │ P005       ┆ 5001    ┆ angers ┆ 2016-08-19  ┆ 2016-08-24  ┆ 0          ┆ 0          ┆ C349       │
# │            ┆         ┆        ┆ 11:00:00    ┆ 10:00:00    ┆            ┆            ┆            │
# │ P006       ┆ 6001    ┆ brest  ┆ 2017-05-06  ┆ 2017-05-12  ┆ 0          ┆ 0          ┆ null       │
# │            ┆         ┆        ┆ 09:20:00    ┆ 11:30:00    ┆            ┆            ┆            │
# │ P008       ┆ 8001    ┆ tours  ┆ 2017-09-10  ┆ 2017-09-16  ┆ 0          ┆ 0          ┆ I693       │
# │            ┆         ┆        ┆ 13:00:00    ┆ 09:30:00    ┆            ┆            ┆            │
# │ P009       ┆ 9001    ┆ angers ┆ 2014-12-03  ┆ 2014-12-09  ┆ 0          ┆ 0          ┆ null       │
# │            ┆         ┆        ┆ 10:15:00    ┆ 14:20:00    ┆            ┆            ┆            │
# │ P010       ┆ 10001   ┆ brest  ┆ 2015-04-18  ┆ 2015-04-23  ┆ 0          ┆ 0          ┆ I48        │
# │            ┆         ┆        ┆ 12:20:00    ┆ 10:00:00    ┆            ┆            ┆            │
# └────────────┴─────────┴────────┴─────────────┴─────────────┴────────────┴────────────┴────────────┘

# %%
data_for_score = (
    preceding_hosps_of_included_patients_with_cim10
    .select(["patient_id", "concept_code"])
    .filter(pl.col("concept_code").is_not_null())
    .join(
        included_patient_with_comorbidity_drug_demo
        .select(["patient_id", "age_at_admission"])
        .unique(),
        how="left",
        on="patient_id"
    )
    .unique()
)
data_for_score_pd = data_for_score.to_pandas()

# %%
charlson = comorbidity(
    score="charlson",
    df=data_for_score_pd,
    id_col="patient_id",
    code_col="concept_code",
    age_col="age_at_admission",
    implementation="quan",
)

hfrs = comorbidity(
    score="hfrs",
    df=data_for_score_pd,
    id_col="patient_id",
    code_col="concept_code",
    age_col="age_at_admission",
)

# %%
hfrs
# Out:
#   patient_id  HFRS Score
# 0       P002         0.0
# 1       P010         0.0
# 2       P008         3.7
# 3       P003         1.4
# 4       P004         0.0
# 5       P001         0.0
# 6       P005         0.0

# %%
charlson_pl = pl.from_pandas(charlson)
hfrs_pl = pl.from_pandas(hfrs)

charlson_selected = charlson_pl.select([
    "patient_id",
    "Charlson Comorbidity Score"
])

hfrs_selected = hfrs_pl.select([
    "patient_id",
    "HFRS Score"
])

final_patient_data = (
    included_patient_with_comorbidity_drug_demo
    .join(charlson_selected, on="patient_id", how="left")
    .join(hfrs_selected, on="patient_id", how="left")
    .with_columns([
        pl.col("Charlson Comorbidity Score").fill_null(0),
        pl.col("HFRS Score").fill_null(0),
    ])
)

# %%
final_patient_data
# Out:
# shape: (10, 32)
# ┌─────────────┬─────────┬────────┬─────────────┬───┬─────────────┬────────────┬────────────┬───────┐
# │ patient_id  ┆ hosp_id ┆ centre ┆ hosp_admiss ┆ … ┆ death_date  ┆ age_at_adm ┆ Charlson   ┆ HFRS  │
# │ ---         ┆ ---     ┆ ---    ┆ ion_datetim ┆   ┆ ---         ┆ ission     ┆ Comorbidit ┆ Score │
# │ str         ┆ i64     ┆ str    ┆ e           ┆   ┆ date        ┆ ---        ┆ y Score    ┆ ---   │
# │             ┆         ┆        ┆ ---         ┆   ┆             ┆ i32        ┆ ---        ┆ f64   │
# │             ┆         ┆        ┆ datetime[μs ┆   ┆             ┆            ┆ i64        ┆       │
# │             ┆         ┆        ┆ ]           ┆   ┆             ┆            ┆            ┆       │
# ╞═════════════╪═════════╪════════╪═════════════╪═══╪═════════════╪════════════╪════════════╪═══════╡
# │ P001        ┆ 1002    ┆ angers ┆ 2018-07-04  ┆ … ┆ 2018-09-21  ┆ 85         ┆ 0          ┆ 0.0   │
# │             ┆         ┆        ┆ 11:15:00    ┆   ┆             ┆            ┆            ┆       │
# │ P002        ┆ 2002    ┆ brest  ┆ 2019-01-18  ┆ … ┆ null        ┆ 84         ┆ 1          ┆ 0.0   │
# │             ┆         ┆        ┆ 13:20:00    ┆   ┆             ┆            ┆            ┆       │
# │ P003        ┆ 3002    ┆ nantes ┆ 2019-04-09  ┆ … ┆ 2020-12-04  ┆ 83         ┆ 3          ┆ 1.4   │
# │             ┆         ┆        ┆ 09:15:00    ┆   ┆             ┆            ┆            ┆       │
# │ P004        ┆ 4002    ┆ tours  ┆ 2018-03-03  ┆ … ┆ null        ┆ 82         ┆ 1          ┆ 0.0   │
# │             ┆         ┆        ┆ 07:50:00    ┆   ┆             ┆            ┆            ┆       │
# │ P005        ┆ 5002    ┆ angers ┆ 2019-02-01  ┆ … ┆ 2019-03-17  ┆ 81         ┆ 2          ┆ 0.0   │
# │             ┆         ┆        ┆ 14:10:00    ┆   ┆             ┆            ┆            ┆       │
# │ P006        ┆ 6002    ┆ brest  ┆ 2020-06-17  ┆ … ┆ null        ┆ 81         ┆ 0          ┆ 0.0   │
# │             ┆         ┆        ┆ 10:45:00    ┆   ┆             ┆            ┆            ┆       │
# │ P007        ┆ 7001    ┆ nantes ┆ 2020-07-22  ┆ … ┆ null        ┆ 81         ┆ 0          ┆ 0.0   │
# │             ┆         ┆        ┆ 08:30:00    ┆   ┆             ┆            ┆            ┆       │
# │ P008        ┆ 8002    ┆ tours  ┆ 2020-12-05  ┆ … ┆ 2021-07-02  ┆ 80         ┆ 1          ┆ 3.7   │
# │             ┆         ┆        ┆ 06:45:00    ┆   ┆             ┆            ┆            ┆       │
# │ P009        ┆ 9002    ┆ angers ┆ 2017-01-26  ┆ … ┆ null        ┆ 83         ┆ 0          ┆ 0.0   │
# │             ┆         ┆        ┆ 09:00:00    ┆   ┆             ┆            ┆            ┆       │
# │ P010        ┆ 10002   ┆ brest  ┆ 2020-03-21  ┆ … ┆ 2020-04-11  ┆ 83         ┆ 0          ┆ 0.0   │
# │             ┆         ┆        ┆ 16:30:00    ┆   ┆             ┆            ┆            ┆       │
# └─────────────┴─────────┴────────┴─────────────┴───┴─────────────┴────────────┴────────────┴───────┘

# %%
final_patient_data = final_patient_data.with_columns([
    (
        pl.col("beta_blocker").fill_null(0)
        + pl.max_horizontal([
            pl.col("ACEI").fill_null(0),
            pl.col("ARB").fill_null(0),
            pl.col("ARNI").fill_null(0),
        ])
        + pl.col("anti_aldosterone").fill_null(0)
        + pl.col("sglt2i").fill_null(0)
    ).alias("OMT_component_score")
])

# %%
final_patient_data
# Out:
# shape: (10, 33)
# ┌─────────────┬─────────┬────────┬─────────────┬───┬─────────────┬────────────┬───────┬────────────┐
# │ patient_id  ┆ hosp_id ┆ centre ┆ hosp_admiss ┆ … ┆ age_at_admi ┆ Charlson   ┆ HFRS  ┆ OMT_compon │
# │ ---         ┆ ---     ┆ ---    ┆ ion_datetim ┆   ┆ ssion       ┆ Comorbidit ┆ Score ┆ ent_score  │
# │ str         ┆ i64     ┆ str    ┆ e           ┆   ┆ ---         ┆ y Score    ┆ ---   ┆ ---        │
# │             ┆         ┆        ┆ ---         ┆   ┆ i32         ┆ ---        ┆ f64   ┆ i8         │
# │             ┆         ┆        ┆ datetime[μs ┆   ┆             ┆ i64        ┆       ┆            │
# │             ┆         ┆        ┆ ]           ┆   ┆             ┆            ┆       ┆            │
# ╞═════════════╪═════════╪════════╪═════════════╪═══╪═════════════╪════════════╪═══════╪════════════╡
# │ P001        ┆ 1002    ┆ angers ┆ 2018-07-04  ┆ … ┆ 85          ┆ 0          ┆ 0.0   ┆ 2          │
# │             ┆         ┆        ┆ 11:15:00    ┆   ┆             ┆            ┆       ┆            │
# │ P002        ┆ 2002    ┆ brest  ┆ 2019-01-18  ┆ … ┆ 84          ┆ 1          ┆ 0.0   ┆ 1          │
# │             ┆         ┆        ┆ 13:20:00    ┆   ┆             ┆            ┆       ┆            │
# │ P003        ┆ 3002    ┆ nantes ┆ 2019-04-09  ┆ … ┆ 83          ┆ 3          ┆ 1.4   ┆ 2          │
# │             ┆         ┆        ┆ 09:15:00    ┆   ┆             ┆            ┆       ┆            │
# │ P004        ┆ 4002    ┆ tours  ┆ 2018-03-03  ┆ … ┆ 82          ┆ 1          ┆ 0.0   ┆ 3          │
# │             ┆         ┆        ┆ 07:50:00    ┆   ┆             ┆            ┆       ┆            │
# │ P005        ┆ 5002    ┆ angers ┆ 2019-02-01  ┆ … ┆ 81          ┆ 2          ┆ 0.0   ┆ 0          │
# │             ┆         ┆        ┆ 14:10:00    ┆   ┆             ┆            ┆       ┆            │
# │ P006        ┆ 6002    ┆ brest  ┆ 2020-06-17  ┆ … ┆ 81          ┆ 0          ┆ 0.0   ┆ 0          │
# │             ┆         ┆        ┆ 10:45:00    ┆   ┆             ┆            ┆       ┆            │
# │ P007        ┆ 7001    ┆ nantes ┆ 2020-07-22  ┆ … ┆ 81          ┆ 0          ┆ 0.0   ┆ 0          │
# │             ┆         ┆        ┆ 08:30:00    ┆   ┆             ┆            ┆       ┆            │
# │ P008        ┆ 8002    ┆ tours  ┆ 2020-12-05  ┆ … ┆ 80          ┆ 1          ┆ 3.7   ┆ 0          │
# │             ┆         ┆        ┆ 06:45:00    ┆   ┆             ┆            ┆       ┆            │
# │ P009        ┆ 9002    ┆ angers ┆ 2017-01-26  ┆ … ┆ 83          ┆ 0          ┆ 0.0   ┆ 0          │
# │             ┆         ┆        ┆ 09:00:00    ┆   ┆             ┆            ┆       ┆            │
# │ P010        ┆ 10002   ┆ brest  ┆ 2020-03-21  ┆ … ┆ 83          ┆ 0          ┆ 0.0   ┆ 0          │
# │             ┆         ┆        ┆ 16:30:00    ┆   ┆             ┆            ┆       ┆            │
# └─────────────┴─────────┴────────┴─────────────┴───┴─────────────┴────────────┴───────┴────────────┘

# %%
df = final_patient_data

# %%
df.schema
# Out:
# Schema([('patient_id', String),
#         ('hosp_id', Int64),
#         ('centre', String),
#         ('hosp_admission_datetime', Datetime(time_unit='us', time_zone=None)),
#         ('hosp_discharge_datetime', Datetime(time_unit='us', time_zone=None)),
#         ('inclusion_flag', Int64),
#         ('icu_stay_flag', Int8),
#         ('Cardiopathie ischémique', Int8),
#         ('Fibrillation atriale', Int8),
#         ('Insuffisance cardiaque chronique', Int8),
#         ('Pacemaker', Int8),
#         ('Pontage aorto-coronarien', Int8),
#         ('Insuffisance rénale chronique', Int8),
#         ("Antécédent d'AVC", Int8),
#         ('Cirrhose', Int8),
#         ('Cancer actif', Int8),
#         ('Immunodépression', Int8),
#         ('Dyslipidémie', Int8),
#         ('Diabète', Int8),
#         ('beta_blocker', Int8),
#         ('ACEI', Int8),
#         ('ARB', Int8),
#         ('ARNI', Int8),
#         ('anti_aldosterone', Int8),
#         ('sglt2i', Int8),
#         ('furosemide', Int8),
#         ('gender', String),
#         ('birth_date', Date),
#         ('death_date', Date),
#         ('age_at_admission', Int32),
#         ('Charlson Comorbidity Score', Int64),
#         ('HFRS Score', Float64),
#         ('OMT_component_score', Int8)])

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.hist(df["Charlson Comorbidity Score"].to_numpy(), bins=20)
plt.xlabel("Charlson Comorbidity Score")
plt.ylabel("Number of patients")
plt.title("Distribution of Charlson Comorbidity Score")
plt.show()

plt.figure()
plt.hist(df["HFRS Score"].to_numpy(), bins=20)
plt.xlabel("HFRS Score")
plt.ylabel("Number of patients")
plt.title("Distribution of HFRS Score")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import polars as pl

score_range = pl.DataFrame({
    "OMT_component_score": [0, 1, 2, 3, 4]
})

omt_counts = (
    df.group_by("OMT_component_score")
    .len()
    .join(score_range, on="OMT_component_score", how="right")
    .with_columns(pl.col("len").fill_null(0))
    .sort("OMT_component_score")
)

x = omt_counts["OMT_component_score"].to_numpy()
y = omt_counts["len"].to_numpy()

plt.figure()
plt.bar(x, y)

plt.xticks([0, 1, 2, 3, 4])
plt.xlabel("OMT component score")
plt.ylabel("Number of patients")
plt.title("Distribution of OMT Component Score")
plt.show()

# %% [markdown]
# import pandas as pd
# import matplotlib.pyplot as plt

# %% [markdown]
# drug_cols = ["beta_blocker", "ACEI", "ARB", "ARNI", "anti_aldosterone", "sglt2i", "furosemide"]
# disease_cols = ["Cardiopathie ischémique", "Fibrillation atriale", "Insuffisance cardiaque chronique",
#                "Pacemaker", "Pontage aorto-coronarien", "Insuffisance rénale chronique", "Antécédent d'AVC",
#                "Cirrhose", "Cancer actif", "Immunodépression", "Dyslipidémie", "Diabète"]

# %% [markdown]
# prevelance_matrix = []
#
# for disease in disease_cols:
#     # Only patients who have this disease
#     patients_with_disease = df.filter(pl.col(disease) == 1)
#
#     # number of these patients
#     n_patients = patients_with_disease.height
#
#     row = []
#
#     for drug in drug_cols:
#
#         # number of patients with this drug
#         patients_with_disease_and_drug = patients_with_disease.filter(
#             pl.col(drug) == 1
#         )
#
#         # Number of patients with this disease and this drug
#         n_drug = patients_with_disease_and_drug.height
#
#         # Percentage of drug use
#         percentage = n_drug/n_patients * 100
#
#         row.append(percentage)
#
#     prevelance_matrix.append(row)
#
# prevelance_df = pd.DataFrame(
#     prevalence_matrix,
#     index=disease_cols,
#     columns=drug_cols
# )

# %% [markdown]
# plt.figure(figsize = (10, 7))
#
# plt.imshow(prevalence_df, aspect="auto")
# plt.colorbar(label="% of patients receiving treatment")
#
# plt.xticks(
#     ticks=range(len(drug_cols)),
#     labels=drug_cols,
#     rotation=45,
#     ha="right"
# )
#
# plt.yticks(
#     ticks=range(len(disease_cols)),
#     labels=disease_cols
# )
#
# plt.title("Treatment prevalence among patients with each comorbidity")
# plt.xlabel("Treatments")
# plt.ylabel("Comorbidities")
#
# plt.tight_layout()
# plt.show()
