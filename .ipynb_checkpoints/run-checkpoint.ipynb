# %%
# %run main.py
# Out:
# ---------------------------------------------------------------------------
# ColumnNotFoundError                       Traceback (most recent call last)
# File ~\Desktop\My_Computer\Professional\Github\patient_cohort\main.py:148
#     131 charlson_score = comorbidity(
#     132
#     133     data_for_score,
#    (...)    139     score=ScoreType.CHARLSON,
#     140 )
#     142 hfrs_score = hfrs(
#     143     data_for_score,
#     144     id_col="patient_id",
#     145     code_col="concept_code")
# --> 148 charlson_selected = charlson_score.select([
#     149     "patient_id",
#     150     "Charlson Comorbidity Score"
#     151 ])
#     153 hfrs_selected = hfrs_score.select([
#     154     "patient_id",
#     155     "HFRS Score"
#     156 ])
#     158 # Add Charlson comorbidity score and HFRS score to the final patient table.
#     159 # A left join keeps all included patients, even if they have no previous CIM-10 diagnosis.
# ...

# %%
import polars as pl

# %%
df = pl.read_parquet("final_patient_data")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pl.read_parquet("final_patient_data")
#
# File ~\anaconda3\envs\arefe_genially\Lib\site-packages\polars\_utils\deprecation.py:128, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     123 @wraps(function)
#     124 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     125     _rename_keyword_argument(
#     126         old_name, new_name, kwargs, function.__qualname__, version
#     127     )
# --> 128     return function(*args, **kwargs)
#
# File ~\anaconda3\envs\arefe_genially\Lib\site-packages\polars\_utils\deprecation.py:128, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     123 @wraps(function)
#     124 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     125     _rename_keyword_argument(
# ...
