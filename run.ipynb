# %%
# %run main.py
# Out:
# ---------------------------------------------------------------------------
# ColumnNotFoundError                       Traceback (most recent call last)
# File ~\Desktop\My_Computer\Professional\Github\patient_cohort\main.py:79
#      72 included_patients_with_comorbidity =comorbidity_utils.get_included_patients_with_comorbidity(
#      73     first_inclusion_hosps,
#      74     patient_comorbidities,
#      75     disease_cols
#      76 )
#      78 # Create binary treatment flags from ATC codes for each treatment record.
# ---> 79 treatments_with_flags = drug.create_treatment_flags(treatments)
#      81 # Convert treatment records into patient-level treatment indicators.
#      82 # For each patient, each treatment flag is 1 if the patient has at least
#      83 # one medication record from that treatment class, otherwise 0.
#      84 patient_treatment_flags = drug.get_patient_treatment_flags(treatments_with_flags)
#
# ...

# %%
import polars as pl

# %%
df = pl.read_parquet("final_patient_data")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pl.read_parquet("final_patient_data")
#
# File ~\anaconda3\envs\arefe_genially\Lib\site-packages\polars\_utils\deprecation.py:128, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     123 @wraps(function)
#     124 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     125     _rename_keyword_argument(
#     126         old_name, new_name, kwargs, function.__qualname__, version
#     127     )
# --> 128     return function(*args, **kwargs)
#
# File ~\anaconda3\envs\arefe_genially\Lib\site-packages\polars\_utils\deprecation.py:128, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     123 @wraps(function)
#     124 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     125     _rename_keyword_argument(
# ...
